# %% [markdown]
# ## Automatic removal of black slices from medical images and masks (NIfTI files)

# %% [markdown]
# This code removes black slices from 3D medical image files and their associated masks in NIfTI format. Black slices do not contain any relevant information, so their removal saves memory and speeds up processing.

# %%
import os
import numpy as np
import nibabel as nib # For loading and saving medical images in NIfTI format.
import logging
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# auxiliary functions

def load_nifti(file_path):
    """
    Loads and returns a NIfTI file.
    """
    try:
        return nib.load(file_path)
    except Exception as e:
        logging.error(f"Error loading file {file_path}: {e}")
        return None

def save_nifti(data, affine, file_path):
    """
    Saves data as NIfTI file.
    """
    try:
        nib.save(nib.Nifti1Image(data, affine), file_path)
    except Exception as e:
        logging.error(f"Error saving file {file_path}: {e}")

# slice filter function

def remove_black_slices(image_path, mask_path, tolerance=1e-6):
    """
    Removes black slices from an image and its associated mask.
    """
    image_nifti = load_nifti(image_path)
    mask_nifti = load_nifti(mask_path)
    
    if image_nifti is None or mask_nifti is None:
        return None, None

    image_data = image_nifti.get_fdata()
    mask_data = mask_nifti.get_fdata()

    # Boolean mask: True for non-black slices
    slice_mask = np.any(mask_data > tolerance, axis=(0, 1))

    # Filtered data based on the mask
    filtered_image_data = image_data[..., slice_mask]
    filtered_mask_data = mask_data[..., slice_mask]

    return filtered_image_data, filtered_mask_data

# Processing of all files with progress indicator

def process_single_file(image_path, mask_path, output_image_path, output_mask_path, tolerance):
    """
    Processes a single image and stores the filtered data.
    """
    filtered_image_data, filtered_mask_data = remove_black_slices(image_path, mask_path, tolerance)

    if filtered_image_data is not None and filtered_mask_data is not None:
        save_nifti(filtered_image_data, nib.load(image_path).affine, output_image_path)
        save_nifti(filtered_mask_data, nib.load(mask_path).affine, output_mask_path)


def process_images_and_masks_parallel(images_dir, masks_dir, output_images_dir, output_masks_dir, tolerance=1e-6):
    """
    Removes black slices from all images and masks in multiple threads.
    """
    os.makedirs(output_images_dir, exist_ok=True)
    os.makedirs(output_masks_dir, exist_ok=True)

    mask_files = os.listdir(masks_dir)

    with ThreadPoolExecutor() as executor, tqdm(total=len(mask_files)) as progress:
        futures = []
        for mask_file in mask_files:
            mask_path = os.path.join(masks_dir, mask_file)
            image_path = os.path.join(images_dir, mask_file)  # Assumption: same names
            
            if not os.path.exists(image_path):
                logging.warning(f"No corresponding image for mask {mask_file} found.")
                progress.update(1)
                continue

            output_image_path = os.path.join(output_images_dir, mask_file)
            output_mask_path = os.path.join(output_masks_dir, mask_file)

            futures.append(executor.submit(
                process_single_file, image_path, mask_path, output_image_path, output_mask_path, tolerance
            ))

        for future in futures:
            future.result()  # Waiting for the task to complete
            progress.update(1)

# main function

def main():
    images_dir = "data/Spleen/images"
    masks_dir = "data/Spleen/masks"
    output_images_dir = "data/Spleen/output_images"
    output_masks_dir = "data/Spleen/output_masks"

    process_images_and_masks_parallel(images_dir, masks_dir, output_images_dir, output_masks_dir)

if __name__ == "__main__":
    main()

# %% [markdown]
# ## Segmentation of medical images with MedSAM model and resumability

# %% [markdown]
# * ### Importing the necessary libraries
#     * #### The code imports basic libraries for scientific computing (numpy), medical imaging (nibabel), machine learning (torch), visualization (matplotlib), and model integration (segment_anything).
#     * #### (tqdm) is used for progress indicators, and logging provides structured logging.
#
# * ### Visualization functions
#     * #### show_mask: Visualizes a segmentation mask with transparent color coverage.
#     * #### show_box: Draws a bounding box that frames the area of ​​the mask.
#
# * ### Inference with MedSAM
#     * #### medsam_inference:
#         * ##### Uses the MedSAM model to create a segmentation for a medical image.
#         * ##### Takes an image embedding and a bounding box as input and returns a binary segmentation mask.
#         * ##### The results are scaled and returned as a NumPy array.
#
# * ### Device definition
#     * ####  The system automatically detects if a GPU is available (torch.cuda.is_available()) and selects it for compute-intensive tasks. Otherwise, the CPU is used.
#
# * ### Loading the MedSAM model
#     * #### A pre-trained MedSAM model (vit_b) is loaded, moved to the previously defined device and put into evaluation mode (eval).
#     * #### The path to the model checkpoint (sam_vit_b_01ec64.pth) is specified.
#
# * ### Directory structure
#     * #### images_dir: Contains the medical images (NIfTI files).
#     * #### masks_dir: Contains the associated masks.
#     * #### Stores the segmentation results (visualizations and created masks).
#
# * ### Total number of slices
#     * #### calculate_total_slices: Calculates the number of slices in all NIfTI images in the directory.
#
# * ### Segmentation with continuation
#     * #### process_images_and_masks_with_resume:
#         * ##### File processing: If a file is missing, a warning is issued.
#         * ##### Slice processing: Each slice of an image is processed individually.
#         * ##### Bounding box detection: A bounding box is calculated based on non-empty pixels of the mask.
#         * ##### Image preprocessing: Images are scaled to 1024x1024 and normalized to meet the requirements of the MedSAM model.
#         * ##### Segmentation inference: The MedSAM model creates the segmentation for each slice.
#         * ##### Result storage: Visualizations (with bounding box and mask) and the binary segmentation mask are saved in the output directory.
#         * ##### Memory cleaning: Memory-intensive objects are deleted and the garbage collector is called.
# * ### Progress bar:
#     * #### tqdm shows the progress of processing
#
# * ### Main program
#     * #### At the end, the function process_images_and_masks_with_resume is called to start the segmentation.
#     * #### Optionally, processing can be continued from a specific file and a specific slice.

# %%
# pip install torch torchvision torchaudio

# %%
# !where python

# %%
# !python --version

# %%
# !pip install torch torchvision

# %%
import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from skimage import transform
import torch
import torch.nn.functional as F
from segment_anything import sam_model_registry
import gc  # for memory cleanup
from tqdm import tqdm
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %% visualization functions
def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([251 / 255, 252 / 255, 30 / 255, 0.6])  # yellow with transparency
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)

def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor="blue", facecolor=(0, 0, 0, 0), lw=2))

@torch.no_grad()
def medsam_inference(medsam_model, img_embed, box_1024, H, W):
    box_torch = torch.as_tensor(box_1024, dtype=torch.float, device=img_embed.device)
    if len(box_torch.shape) == 2:
        box_torch = box_torch[:, None, :]  # (B, 1, 4)

    sparse_embeddings, dense_embeddings = medsam_model.prompt_encoder(
        points=None,
        boxes=box_torch,
        masks=None,
    )
    low_res_logits, _ = medsam_model.mask_decoder(
        image_embeddings=img_embed,
        image_pe=medsam_model.prompt_encoder.get_dense_pe(),
        sparse_prompt_embeddings=sparse_embeddings,
        dense_prompt_embeddings=dense_embeddings,
        multimask_output=False,
    )

    low_res_pred = torch.sigmoid(low_res_logits)  # (1, 1, 256, 256)
    low_res_pred = F.interpolate(
        low_res_pred, size=(H, W), mode="bilinear", align_corners=False
    )  # (1, 1, H, W)
    low_res_pred = low_res_pred.squeeze().cpu().numpy()  # (H, W)
    medsam_seg = (low_res_pred > 0.5).astype(np.uint8)
    return medsam_seg

# %% Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logging.info(f"Verwende Gerät: {device}")

# %% Modell laden
MedSAM_CKPT_PATH = "Checkpoint/sam_vit_b_01ec64.pth"  # path to the checkpoint
medsam_model = sam_model_registry["vit_b"](checkpoint=MedSAM_CKPT_PATH)
medsam_model = medsam_model.to(device)
medsam_model.eval()
logging.info("MedSAM model loaded successfully.")

# %% Verzeichnisse
# images_dir = "data/Lung Tumors/output_images"
# masks_dir = "data/Lung Tumors/output_masks"
# output_dir = "data/Lung Tumors/segmentation_results"
# os.makedirs(output_dir, exist_ok=True)

# %% Calculate total number of slices
def calculate_total_slices(images_dir):
    total_slices = 0
    for image_file in os.listdir(images_dir):
        image_path = os.path.join(images_dir, image_file)
        if not image_file.endswith(".nii") and not image_file.endswith(".nii.gz"):
            continue
        nifti_image = nib.load(image_path)
        total_slices += nifti_image.shape[2]  # Z-Achse
    return total_slices

# %% Optimized segmentation with progress display and logging
def process_images_and_masks_with_resume(images_dir, masks_dir, output_dir, resume_file=None, resume_slice=None):
    """
    Continues segmentation starting from a specific file and slice.
    :param images_dir: Directory containing medical images.
    :param masks_dir: Directory containing masks.
    :param output_dir: Directory for the results.
    :param resume_file: Name of the file to continue from (e.g. 'lung_016.nii.gz').
    :param resume_slice: Slice index to continue from in the file.
    """
    resume = resume_file is None  # If no resume file is specified, start from the beginning

    mask_files = sorted(os.listdir(masks_dir))  # Ensure alphabetical order

    with tqdm(total=len(mask_files), desc="Dateien", unit="Datei") as progress:
        for mask_file in mask_files:
            mask_path = os.path.join(masks_dir, mask_file)
            image_path = os.path.join(images_dir, mask_file)

            if not os.path.exists(image_path):
                logging.warning(f"Fehlendes Bild für Maske: {mask_file}")
                progress.update(1)
                continue

            # When we reach the resume file, activate the resume mode
            if not resume and mask_file == resume_file:
                resume = True

            if not resume:  # Skip files before the resume file
                progress.update(1)
                continue

            # Upload medical image and mask
            nifti_image = nib.load(image_path)
            nifti_mask = nib.load(mask_path)

            image_data = nifti_image.get_fdata()
            mask_data = nifti_mask.get_fdata()

            total_slices = image_data.shape[2]

            # Set the start slice for the resume file
            slice_start = resume_slice if mask_file == resume_file and resume_slice is not None else 0

            with tqdm(total=total_slices, desc=f"Slices in {mask_file}", unit="Slice") as slice_progress:
                for slice_idx in range(slice_start, total_slices):
                    logging.info(f"Process Slice {slice_idx} for file {mask_file}")
                    image_slice = image_data[:, :, slice_idx]
                    mask_slice = mask_data[:, :, slice_idx]

                    if np.sum(mask_slice) == 0:  # Skip empty masks
                        slice_progress.update(1)
                        continue

                    # Calculate Bounding Box from Mask
                    non_zero_coords = np.argwhere(mask_slice > 0)
                    y_min, x_min = non_zero_coords.min(axis=0)
                    y_max, x_max = non_zero_coords.max(axis=0)
                    box_np = np.array([[x_min, y_min, x_max, y_max]])

                    # preprocessing of the image
                    H, W = image_slice.shape
                    resized_image = transform.resize(
                        image_slice, (1024, 1024), order=3, preserve_range=True, anti_aliasing=True
                    )
                    normalized_image = (resized_image - resized_image.min()) / max(resized_image.max() - resized_image.min(), 1e-8)
                    # normalized_image = resized_image / 255.0

                    image_rgb = np.stack([normalized_image] * 3, axis=-1)

                    box_1024 = box_np / np.array([W, H, W, H]) * 1024
                    image_tensor = torch.tensor(image_rgb).float().permute(2, 0, 1).unsqueeze(0).to(device)

                    # MedSAM inference
                    with torch.no_grad():
                        image_embedding = medsam_model.image_encoder(image_tensor)
                        medsam_seg = medsam_inference(medsam_model, image_embedding, box_1024, 1024, 1024)

                    # Save results
                    visualization_file = os.path.join(output_dir, f"{mask_file}_slice_{slice_idx}_visualization.png")
                    seg_file = os.path.join(output_dir, f"{mask_file}_slice_{slice_idx}_segmentation.png")

                    fig, ax = plt.subplots(1, 2, figsize=(12, 6))
                    ax[0].imshow(resized_image, cmap="gray")
                    show_box(box_1024[0], ax[0])
                    ax[0].set_title(f"Original Slice {slice_idx} mit Bounding Box")
                    ax[1].imshow(resized_image, cmap="gray")
                    show_mask(medsam_seg, ax[1])
                    ax[1].set_title(f"Segmentierung Slice {slice_idx}")
                    plt.savefig(visualization_file)
                    plt.close(fig)

                    plt.imsave(seg_file, medsam_seg, cmap="gray")

                    # clean memory
                    del image_tensor, image_embedding, medsam_seg
                    gc.collect()

                    slice_progress.update(1)

            logging.info(f"Done with file {mask_file}")
            progress.update(1)

# Define directories
images_dir = "data/Spleen/output_images"
masks_dir = "data/Spleen/output_masks"
output_dir = "data/Spleen/segmentation_results"
os.makedirs(output_dir, exist_ok=True)

# continue processing
process_images_and_masks_with_resume(
    images_dir=images_dir,
    masks_dir=masks_dir,
    output_dir=output_dir,
    resume_file="spleen_2.nii.gz",  # File from which to continue
    resume_slice=0             # Slice from which to continue in the file
)

# %%
# -*- coding: utf-8 -*-
import os
import json
import time
import csv
import gc
import logging
from typing import Optional, Tuple

import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from skimage import transform
import torch
import torch.nn.functional as F
from segment_anything import sam_model_registry
from tqdm import tqdm

# ========================= Logging =========================
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# =================== Visualisierungsfunktionen ===================
def show_mask(mask, ax, random_color=False):
    import numpy as np
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([251 / 255, 252 / 255, 30 / 255, 0.6])  # Gelb mit Transparenz
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)

def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor="blue", facecolor=(0, 0, 0, 0), lw=2))

# ================== MedSAM Inferenz ==================
@torch.no_grad()
def medsam_inference(medsam_model, img_embed, box_1024, H, W):
    box_torch = torch.as_tensor(box_1024, dtype=torch.float, device=img_embed.device)
    if len(box_torch.shape) == 2:
        box_torch = box_torch[:, None, :]  # (B, 1, 4)

    sparse_embeddings, dense_embeddings = medsam_model.prompt_encoder(
        points=None, boxes=box_torch, masks=None
    )
    low_res_logits, _ = medsam_model.mask_decoder(
        image_embeddings=img_embed,
        image_pe=medsam_model.prompt_encoder.get_dense_pe(),
        sparse_prompt_embeddings=sparse_embeddings,
        dense_prompt_embeddings=dense_embeddings,
        multimask_output=False,
    )

    low_res_pred = torch.sigmoid(low_res_logits)
    low_res_pred = torch.nn.functional.interpolate(
        low_res_pred, size=(H, W), mode="bilinear", align_corners=False
    )
    low_res_pred = low_res_pred.squeeze().detach().cpu().numpy()
    medsam_seg = (low_res_pred > 0.5).astype(np.uint8)
    return medsam_seg

# =================== Gerät & Modell ===================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logging.info(f"Verwende Gerät: {device}")

MedSAM_CKPT_PATH = "Checkpoint/sam_vit_b_01ec64.pth"
medsam_model = sam_model_registry["vit_b"](checkpoint=MedSAM_CKPT_PATH).to(device).eval()
logging.info("MedSAM Modell erfolgreich geladen.")

# =================== Helpers ===================
def _fmt(sec: float) -> str:
    h, r = divmod(sec, 3600)
    m, s = divmod(r, 60)
    return f"{int(h):02d}:{int(m):02d}:{s:05.2f}"

def _sum_seconds_from_csv(csv_path: str) -> float:
    """
    Summiert die Spalte 'seconds' aus timing_per_slice.csv über alle Runs.
    Robuste Auswertung ohne pandas.
    """
    if not os.path.exists(csv_path):
        return 0.0
    total = 0.0
    try:
        with open(csv_path, "r", encoding="utf-8") as f:
            reader = csv.DictReader(f)
            if not reader.fieldnames or "seconds" not in reader.fieldnames:
                return 0.0
            for row in reader:
                try:
                    total += float(row["seconds"])
                except Exception:
                    continue
    except Exception as e:
        logging.warning(f"Konnte CSV nicht auswerten ({csv_path}): {e}")
    return total

# =================== Zeitmessung (Wall-Clock + CSV-Gesamt) ===================
def _load_runtime_state(state_path: str) -> dict:
    if os.path.exists(state_path):
        try:
            with open(state_path, "r", encoding="utf-8") as f:
                return json.load(f)
        except Exception as e:
            logging.warning(f"Konnte Runtime-State nicht lesen: {e}")
    return {
        "sessions": [],             # [{start, end, elapsed_sec}]
        "total_elapsed_sec": 0.0,   # akkumulierte Wall-Clock-Zeit über Sessions (informativ)
    }

def _save_runtime_state(state_path: str, state: dict):
    with open(state_path, "w", encoding="utf-8") as f:
        json.dump(state, f, indent=2)


def time_run_accumulate(func, state_path: str, seed_timing_csv: str, *args, **kwargs):
    """
    Führt func aus, misst Laufzeit des aktuellen Runs und akkumuliert in state_path.
    Zusätzlich wird am Ende die *echte* Gesamtlaufzeit über alle Neustarts
    aus timing_per_slice.csv (seed_timing_csv) berechnet und geloggt.
    """
    state = _load_runtime_state(state_path)

    start = time.perf_counter()
    start_wall = time.time()
    logging.info("==== Starte Laufzeitmessung (akkumuliert) ====")

    try:
        return func(*args, **kwargs)  # kwargs enthält später timing_csv für die Pipeline
    finally:
        elapsed = time.perf_counter() - start
        end_wall = time.time()

        state["sessions"].append({"start": start_wall, "end": end_wall, "elapsed_sec": elapsed})
        state["total_elapsed_sec"] = float(state.get("total_elapsed_sec", 0.0)) + float(elapsed)
        _save_runtime_state(state_path, state)

        # 1) Wall-Clock (informativ)
        msg1 = f"Aktueller Run: {_fmt(elapsed)} | Akkumuliert (Wall-Clock): {_fmt(state['total_elapsed_sec'])}"
        logging.info(msg1)

        # 2) CSV-basierte Gesamtsumme (entscheidend) – aus seed_timing_csv
        total_csv_sec = _sum_seconds_from_csv(seed_timing_csv)
        msg2 = f"Akkumulierte Gesamtlaufzeit (aus CSV, alle Neustarts): {_fmt(total_csv_sec)}"
        logging.info(msg2)

        with open("runtime_log.txt", "a", encoding="utf-8") as f:
            f.write(msg1 + "\n")
            f.write(msg2 + "\n")

# =================== Resume-Checkpoint ===================
def save_resume_state(checkpoint_path: str, filename: str, slice_idx: int):
    state = {"resume_file": filename, "resume_slice": slice_idx}
    with open(checkpoint_path, "w", encoding="utf-8") as f:
        json.dump(state, f)

def load_resume_state(checkpoint_path: str) -> Tuple[Optional[str], Optional[int]]:
    if os.path.exists(checkpoint_path):
        try:
            with open(checkpoint_path, "r", encoding="utf-8") as f:
                state = json.load(f)
            return state.get("resume_file"), state.get("resume_slice")
        except Exception as e:
            logging.warning(f"Checkpoint konnte nicht gelesen werden: {e}")
    return None, None

# =================== Pipeline (Spleen) ===================
def process_images_and_masks_with_resume(
    images_dir: str,
    masks_dir: str,
    output_dir: str,
    checkpoint_path: str,
    timing_csv: str,
    resume_file: Optional[str] = None,
    resume_slice: Optional[int] = None,
    use_auto_resume: bool = True,
):
    """
    - Segmentiert alle Spleen-Volumes sliceweise mit MedSAM.
    - Schreibt VOR JEDEM Slice einen Resume-Checkpoint.
    - Hängt pro Slice die Laufzeit an timing_csv an (persistiert über Neustarts).
    """
    os.makedirs(output_dir, exist_ok=True)

    # Auto-Resume
    if use_auto_resume and (resume_file is None and resume_slice is None):
        cf, cs = load_resume_state(checkpoint_path)
        if cf is not None:
            logging.info(f"Automatischer Resume → Datei={cf}, Slice={cs}")
            resume_file, resume_slice = cf, cs

    # timing CSV initialisieren (Header nur einmal)
    if not os.path.exists(timing_csv):
        with open(timing_csv, "w", newline="", encoding="utf-8") as fcsv:
            csv.writer(fcsv).writerow(["file", "slice_idx", "seconds"])

    # Dateiliste
    nii_files = sorted([f for f in os.listdir(images_dir) if f.endswith((".nii", ".nii.gz"))])
    resume_armed = resume_file is None  # erst ab resume_file loslegen

    with tqdm(total=len(nii_files), desc="Dateien", unit="Datei") as prog_files:
        for image_file in nii_files:
            image_path = os.path.join(images_dir, image_file)
            mask_path  = os.path.join(masks_dir,  image_file)  # gleicher Dateiname erwartet

            if not os.path.exists(mask_path):
                logging.warning(f"Fehlende Maske: {image_file}")
                prog_files.update(1)
                continue

            if not resume_armed:
                if image_file == resume_file:
                    resume_armed = True
                else:
                    prog_files.update(1)
                    continue

            # NIfTI laden
            nifti_image = nib.load(image_path)
            nifti_mask  = nib.load(mask_path)
            img = nifti_image.get_fdata()
            msk = nifti_mask.get_fdata()

            total_slices = img.shape[2]
            slice_start = resume_slice if (image_file == resume_file and resume_slice is not None) else 0

            with tqdm(total=total_slices, desc=f"Slices in {image_file}", unit="Slice") as prog_slices:
                for slice_idx in range(slice_start, total_slices):
                    t0 = time.perf_counter()
                    try:
                        # Checkpoint vor der Bearbeitung schreiben
                        save_resume_state(checkpoint_path, image_file, slice_idx)

                        image_slice = img[:, :, slice_idx]
                        mask_slice  = msk[:, :, slice_idx]

                        if np.sum(mask_slice) == 0:
                            # leere GT → Überspringen (aber Zeit/Progress zählen)
                            continue

                        # Vorverarbeitung
                        H, W = image_slice.shape
                        resized_image = transform.resize(
                            image_slice, (1024, 1024), order=3, preserve_range=True, anti_aliasing=True
                        )
                        normalized_image = (resized_image - resized_image.min()) / max(resized_image.ptp(), 1e-8)
                        image_rgb = np.stack([normalized_image] * 3, axis=-1)
                        image_tensor = torch.tensor(image_rgb).float().permute(2, 0, 1).unsqueeze(0).to(device)

                        # Bounding Box aus Maske
                        yx = np.argwhere(mask_slice > 0)
                        y_min, x_min = yx.min(axis=0)
                        y_max, x_max = yx.max(axis=0)
                        box_np = np.array([[x_min, y_min, x_max, y_max]])
                        box_1024 = box_np / np.array([W, H, W, H]) * 1024

                        # MedSAM
                        with torch.no_grad():
                            image_embedding = medsam_model.image_encoder(image_tensor)
                            medsam_seg = medsam_inference(medsam_model, image_embedding, box_1024, 1024, 1024)

                        # Speichern
                        vis_file = os.path.join(output_dir, f"{image_file}_slice_{slice_idx}_visualization.png")
                        seg_file = os.path.join(output_dir, f"{image_file}_slice_{slice_idx}_segmentation.png")

                        fig, ax = plt.subplots(1, 2, figsize=(12, 6))
                        ax[0].imshow(resized_image, cmap="gray")
                        show_box(box_1024[0], ax[0])
                        ax[0].set_title(f"Original Slice {slice_idx} mit Bounding Box")
                        ax[1].imshow(resized_image, cmap="gray")
                        show_mask(medsam_seg, ax[1])
                        ax[1].set_title(f"Segmentierung Slice {slice_idx}")
                        plt.savefig(vis_file)
                        plt.close(fig)

                        plt.imsave(seg_file, medsam_seg, cmap="gray")

                        # Cleanup
                        del image_tensor, image_embedding, medsam_seg
                        gc.collect()

                    except Exception as e:
                        logging.error(f"Fehler bei {image_file} Slice {slice_idx}: {e}")
                    finally:
                        # Slice-Zeit anhängen (persistiert über alle Runs)
                        elapsed_slice = time.perf_counter() - t0
                        with open(timing_csv, "a", newline="", encoding="utf-8") as fcsv:
                            csv.writer(fcsv).writerow([image_file, slice_idx, f"{elapsed_slice:.4f}"])
                        prog_slices.update(1)

            prog_files.update(1)

    # Fertig → Checkpoint löschen
    if os.path.exists(checkpoint_path):
        os.remove(checkpoint_path)
        logging.info("Checkpoint entfernt (Pipeline abgeschlossen).")

# =================== AUSFÜHRUNG (Spleen) ===================
if __name__ == "__main__":
    images_dir = os.path.join("data", "Spleen", "output_images")
    masks_dir  = os.path.join("data", "Spleen", "output_masks")
    output_dir = os.path.join("data", "Spleen", "segmentation_results_with_run_time")
    os.makedirs(output_dir, exist_ok=True)

    checkpoint_path = os.path.join(output_dir, "resume_checkpoint.json")
    timing_csv      = os.path.join(output_dir, "timing_per_slice.csv")
    runtime_state   = os.path.join(output_dir, "runtime_state.json")

    # Manuelles Resume (optional). Wenn None/None → Auto-Resume via JSON.
    manual_resume_file  = "spleen_63.nii.gz"   # z.B. "spleen_44.nii.gz"
    manual_resume_slice = 20   # z.B. 0

    # Lauf starten (Wall-Clock akkumuliert + CSV-basierte Gesamtzeit)

    time_run_accumulate(
        process_images_and_masks_with_resume,
        runtime_state,              # state_path
        seed_timing_csv=timing_csv, # <-- NUR für den Wrapper (Summe am Ende)
        images_dir=images_dir,
        masks_dir=masks_dir,
        output_dir=output_dir,
        checkpoint_path=checkpoint_path,
        timing_csv=timing_csv,      # <-- für die Pipeline-Funktion (Pflichtargument)
        resume_file=manual_resume_file,
        resume_slice=manual_resume_slice,
        use_auto_resume=True,
    )

    # Optional: Hier könntest du noch einmal explizit die CSV-Gesamtzeit loggen:
    total_csv_sec = _sum_seconds_from_csv(timing_csv)
    logging.info(f"[FINAL] Gesamtlaufzeit aus CSV (alle Neustarts): {_fmt(total_csv_sec)}")
# Out:
# 2025-09-06 23:37:45,973 - INFO - Verwende Gerät: cpu
# 2025-09-06 23:37:56,580 - INFO - MedSAM Modell erfolgreich geladen.
# 2025-09-06 23:37:56,602 - INFO - ==== Starte Laufzeitmessung (akkumuliert) ====
# Dateien:   0%|                                                                               | 0/41 [00:00<?, ?Datei/s]
# Slices in spleen_63.nii.gz:   0%|                                                            | 0/25 [00:00<?, ?Slice/s]
# Slices in spleen_63.nii.gz:   4%|██                                                  | 1/25 [00:31<12:34, 31.44s/Slice]
# Slices in spleen_63.nii.gz:   8%|████▏                                               | 2/25 [01:02<11:52, 30.97s/Slice]
# Slices in spleen_63.nii.gz:  12%|██████▏                                             | 3/25 [01:33<11:26, 31.22s/Slice]
# Slices in spleen_63.nii.gz:  16%|████████▎                                           | 4/25 [02:04<10:49, 30.93s/Slice]
# Slices in spleen_63.nii.gz:  20%|██████████▍                                         | 5/25 [02:34<10:17, 30.89s/Slice]
# Dateien:  95%|██████████████████████████████████████████████████████████████████▌   | 39/41 [02:34<00:07,  3.97s/Datei]
# Slices in spleen_8.nii.gz:   0%|                                                             | 0/19 [00:00<?, ?Slice/s]
# Slices in spleen_8.nii.gz:   5%|██▊                                                  | 1/19 [00:30<09:11, 30.63s/Slice]
# Slices in spleen_8.nii.gz:  11%|█████▌                                               | 2/19 [01:02<08:49, 31.16s/Slice]
# Slices in spleen_8.nii.gz:  16%|████████▎                                            | 3/19 [01:32<08:14, 30.92s/Slice]
# Slices in spleen_8.nii.gz:  21%|███████████▏                                         | 4/19 [02:04<07:49, 31.31s/Slice]
# Slices in spleen_8.nii.gz:  26%|█████████████▉                                       | 5/19 [02:38<07:28, 32.04s/Slice]
# Slices in spleen_8.nii.gz:  32%|████████████████▋                                    | 6/19 [03:09<06:53, 31.81s/Slice]
# Slices in spleen_8.nii.gz:  37%|███████████████████▌                                 | 7/19 [03:40<06:18, 31.53s/Slice]
# Slices in spleen_8.nii.gz:  42%|██████████████████████▎                              | 8/19 [04:11<05:45, 31.39s/Slice]
# Slices in spleen_8.nii.gz:  47%|█████████████████████████                            | 9/19 [04:42<05:12, 31.24s/Slice]
# Slices in spleen_8.nii.gz:  53%|███████████████████████████▎                        | 10/19 [05:12<04:38, 30.94s/Slice]
# Slices in spleen_8.nii.gz:  58%|██████████████████████████████                      | 11/19 [05:43<04:07, 30.98s/Slice]
# Slices in spleen_8.nii.gz:  63%|████████████████████████████████▊                   | 12/19 [06:14<03:35, 30.80s/Slice]
# Slices in spleen_8.nii.gz:  68%|███████████████████████████████████▌                | 13/19 [06:45<03:05, 30.87s/Slice]
# Slices in spleen_8.nii.gz:  74%|██████████████████████████████████████▎             | 14/19 [07:16<02:34, 30.97s/Slice]
# Slices in spleen_8.nii.gz:  79%|█████████████████████████████████████████           | 15/19 [07:46<02:02, 30.66s/Slice]
# Slices in spleen_8.nii.gz:  84%|███████████████████████████████████████████▊        | 16/19 [08:15<01:31, 30.34s/Slice]
# Slices in spleen_8.nii.gz:  89%|██████████████████████████████████████████████▌     | 17/19 [08:45<01:00, 30.21s/Slice]
# Slices in spleen_8.nii.gz:  95%|█████████████████████████████████████████████████▎  | 18/19 [09:15<00:30, 30.22s/Slice]
# Slices in spleen_8.nii.gz: 100%|████████████████████████████████████████████████████| 19/19 [09:45<00:00, 30.83s/Slice]
# Dateien:  98%|████████████████████████████████████████████████████████████████████▎ | 40/41 [12:21<00:24, 24.55s/Datei]
# Slices in spleen_9.nii.gz:   0%|                                                             | 0/25 [00:00<?, ?Slice/s]
# Slices in spleen_9.nii.gz:   4%|██                                                   | 1/25 [00:29<11:50, 29.62s/Slice]
# Slices in spleen_9.nii.gz:   8%|████▏                                                | 2/25 [01:01<11:46, 30.71s/Slice]
# Slices in spleen_9.nii.gz:  12%|██████▎                                              | 3/25 [01:30<11:06, 30.30s/Slice]
# Slices in spleen_9.nii.gz:  16%|████████▍                                            | 4/25 [02:01<10:34, 30.23s/Slice]
# Slices in spleen_9.nii.gz:  20%|██████████▌                                          | 5/25 [02:31<10:03, 30.17s/Slice]
# Slices in spleen_9.nii.gz:  24%|████████████▋                                        | 6/25 [03:03<09:48, 30.99s/Slice]
# Slices in spleen_9.nii.gz:  28%|██████████████▊                                      | 7/25 [03:33<09:11, 30.65s/Slice]
# Slices in spleen_9.nii.gz:  32%|████████████████▉                                    | 8/25 [04:03<08:36, 30.36s/Slice]
# Slices in spleen_9.nii.gz:  36%|███████████████████                                  | 9/25 [04:33<08:02, 30.18s/Slice]
# Slices in spleen_9.nii.gz:  40%|████████████████████▊                               | 10/25 [05:02<07:30, 30.00s/Slice]
# Slices in spleen_9.nii.gz:  44%|██████████████████████▉                             | 11/25 [05:33<07:04, 30.29s/Slice]
# Slices in spleen_9.nii.gz:  48%|████████████████████████▉                           | 12/25 [06:06<06:42, 30.97s/Slice]
# Slices in spleen_9.nii.gz:  52%|███████████████████████████                         | 13/25 [06:36<06:10, 30.87s/Slice]
# Slices in spleen_9.nii.gz:  56%|█████████████████████████████                       | 14/25 [07:08<05:41, 31.01s/Slice]
# Slices in spleen_9.nii.gz:  60%|███████████████████████████████▏                    | 15/25 [07:39<05:10, 31.00s/Slice]
# Slices in spleen_9.nii.gz:  64%|█████████████████████████████████▎                  | 16/25 [08:09<04:38, 30.94s/Slice]
# Slices in spleen_9.nii.gz:  68%|███████████████████████████████████▎                | 17/25 [08:40<04:05, 30.75s/Slice]
# Slices in spleen_9.nii.gz:  72%|█████████████████████████████████████▍              | 18/25 [09:10<03:34, 30.68s/Slice]
# Slices in spleen_9.nii.gz:  76%|███████████████████████████████████████▌            | 19/25 [09:40<03:03, 30.53s/Slice]
# Slices in spleen_9.nii.gz:  80%|█████████████████████████████████████████▌          | 20/25 [10:11<02:32, 30.52s/Slice]
# Slices in spleen_9.nii.gz:  84%|███████████████████████████████████████████▋        | 21/25 [10:41<02:01, 30.49s/Slice]
# Slices in spleen_9.nii.gz:  88%|█████████████████████████████████████████████▊      | 22/25 [11:13<01:32, 30.77s/Slice]
# Slices in spleen_9.nii.gz:  92%|███████████████████████████████████████████████▊    | 23/25 [11:43<01:01, 30.74s/Slice]
# Slices in spleen_9.nii.gz:  96%|█████████████████████████████████████████████████▉  | 24/25 [12:14<00:30, 30.63s/Slice]
# Slices in spleen_9.nii.gz: 100%|████████████████████████████████████████████████████| 25/25 [12:43<00:00, 30.53s/Slice]
# Dateien: 100%|██████████████████████████████████████████████████████████████████████| 41/41 [25:05<00:00, 36.71s/Datei]
# 2025-09-07 00:03:01,657 - INFO - Checkpoint entfernt (Pipeline abgeschlossen).
# 2025-09-07 00:03:01,676 - INFO - Aktueller Run: 00:25:05.07 | Akkumuliert (Wall-Clock): 00:25:05.07
# 2025-09-07 00:03:01,739 - INFO - Akkumulierte Gesamtlaufzeit (aus CSV, alle Neustarts): 10:55:52.90
# 2025-09-07 00:03:01,768 - INFO - [FINAL] Gesamtlaufzeit aus CSV (alle Neustarts): 10:55:52.90

# %%
import pandas as pd

# Pfad zur timing_per_slice.csv
csv_path = "data/Spleen/segmentation_results_with_run_time/timing_per_slice.csv"

# CSV laden
df = pd.read_csv(csv_path)

# Spalte seconds sicher als float laden
df['seconds'] = pd.to_numeric(df['seconds'], errors='coerce')

# Gesamtzeit
total_seconds = df['seconds'].sum()
total_minutes = total_seconds / 60
total_hours = total_seconds / 3600

# Anzahl der Slices
num_slices = len(df)

# Durchschnittszeit
avg_sec = df['seconds'].mean()
avg_min = avg_sec / 60

# Min/Max/Median
min_sec = df['seconds'].min()
max_sec = df['seconds'].max()
median_sec = df['seconds'].median()

# Ausgabe auf der Konsole
print("==== Timing Summary ====")
print(f"Slices verarbeitet : {num_slices}")
print(f"Gesamtzeit        : {total_seconds:.2f} Sekunden")
print(f"                   : {total_minutes:.2f} Minuten")
print(f"                   : {total_hours:.2f} Stunden")
print(f"Durchschnitt/Slice: {avg_sec:.2f} Sekunden ({avg_min:.2f} Minuten)")
print(f"Median/Slice      : {median_sec:.2f} Sekunden")
print(f"Schnellster Slice : {min_sec:.2f} Sekunden")
print(f"Langsamster Slice : {max_sec:.2f} Sekunden")

# Optional: Zusammenfassung in eine Textdatei speichern
summary_path = "data/Spleen/segmentation_results/timing_summary.txt"
with open(summary_path, "w") as f:
    f.write("==== Timing Summary ====\n")
    f.write(f"Slices verarbeitet : {num_slices}\n")
    f.write(f"Gesamtzeit        : {total_seconds:.2f} Sekunden\n")
    f.write(f"                   : {total_minutes:.2f} Minuten\n")
    f.write(f"                   : {total_hours:.2f} Stunden\n")
    f.write(f"Durchschnitt/Slice: {avg_sec:.2f} Sekunden ({avg_min:.2f} Minuten)\n")
    f.write(f"Median/Slice      : {median_sec:.2f} Sekunden\n")
    f.write(f"Schnellster Slice : {min_sec:.2f} Sekunden\n")
    f.write(f"Langsamster Slice : {max_sec:.2f} Sekunden\n")

print(f"\nZusammenfassung gespeichert in {summary_path}")
# Out:
# ==== Timing Summary ====
# Slices verarbeitet : 1060
# Gesamtzeit        : 39352.90 Sekunden
#                    : 655.88 Minuten
#                    : 10.93 Stunden
# Durchschnitt/Slice: 37.13 Sekunden (0.62 Minuten)
# Median/Slice      : 30.19 Sekunden
# Schnellster Slice : 24.31 Sekunden
# Langsamster Slice : 5370.33 Sekunden
#
# Zusammenfassung gespeichert in data/Spleen/segmentation_results/timing_summary.txt

# %% [markdown]
# ## Conversion and adaptation of mask slices from NIfTI files to PNG format for the calculation of Dice Score later

# %% [markdown]
# This code converts masks from medical image files (NIfTI format) to PNG image format.
# The mask slices are converted to binary masks, resized and saved to a destination folder.

# %%
import os
import cv2
import nibabel as nib
import numpy as np
from PIL import Image
import logging

# Logging konfigurieren
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# Eingabe- und Ausgabeordner
input_mask_folder = os.path.join("data", "Spleen", "output_masks")
updated_mask_folder = os.path.join("data", "Spleen", "output_masks_updated")
os.makedirs(updated_mask_folder, exist_ok=True)

# Zielauflösung
target_resolution = (1024, 1024)

# Verarbeitung der Masken
for mask_filename in os.listdir(input_mask_folder):
    if mask_filename.endswith((".nii", ".nii.gz")):
        mask_path = os.path.join(input_mask_folder, mask_filename)
        try:
            mask_nii = nib.load(mask_path)
        except Exception as e:
            logging.error(f"Fehler beim Laden von {mask_filename}: {e}")
            continue

        mask_data = mask_nii.get_fdata()
        base_name = mask_filename.split(".nii")[0]

        for slice_idx in range(mask_data.shape[2]):
            slice_data = mask_data[:, :, slice_idx]
            slice_data = (slice_data > 0).astype(np.uint8) * 255  # Binärmaske

            # Slice-Nummer formatieren und Skalierung durchführen
            slice_number_formatted = f"{slice_idx + 1:02d}"
            updated_filename = f"{base_name}_slice_{slice_number_formatted}_segmentation.png"

            slice_image = Image.fromarray(slice_data)
            slice_image_resized = slice_image.resize(target_resolution, Image.LANCZOS)

            updated_path = os.path.join(updated_mask_folder, updated_filename)
            try:
                slice_image_resized.save(updated_path)
                logging.info(f"Gespeichert: {updated_filename}")
            except Exception as e:
                logging.error(f"Fehler beim Speichern von {updated_filename}: {e}")

logging.info(f"Alle Masken wurden im Ordner '{updated_mask_folder}' gespeichert.")

# %% [markdown]
# ## Calculating the Dice Similarity Coefficient (DSC)

# %%
import os
import numpy as np
import cv2
import logging
import csv
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor

# Logging konfigurieren
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# Ordner mit den Masken
mask_png_folder = os.path.join("data", "Spleen", "output_masks_updated")
segmentation_results_folder = os.path.join("data", "Spleen", "segmentation_results_with_run_time")

# Funktion zur Berechnung des Dice Scores
def dice_score(mask1, mask2):
    intersection = np.sum(mask1 * mask2)
    if np.sum(mask1) + np.sum(mask2) == 0:
        return 1.0  # Sonderfall: Beide Masken sind komplett leer
    dice = (2. * intersection) / (np.sum(mask1) + np.sum(mask2))
    return dice

# Funktion zur Verarbeitung einer einzelnen Datei
def process_single_file(mask_filename):
    base_name = mask_filename.split("_slice_")[0]
    slice_number = mask_filename.split("_slice_")[-1].split("_")[0]
    slice_number_converted = int(slice_number) - 1
    segmentation_filename = f"{base_name}.nii.gz_slice_{slice_number_converted}_segmentation.png"

    mask_png_path = os.path.join(mask_png_folder, mask_filename)
    segmentation_path = os.path.join(segmentation_results_folder, segmentation_filename)

    if os.path.exists(segmentation_path):
        try:
            # Masken laden
            mask_png = cv2.imread(mask_png_path, cv2.IMREAD_GRAYSCALE)
            segmentation = cv2.imread(segmentation_path, cv2.IMREAD_GRAYSCALE)

            # Sicherstellen, dass beide Masken binär sind (0 und 1)
            mask_png = (mask_png > 0).astype(np.uint8)
            segmentation = (segmentation > 0).astype(np.uint8)

            # Dice Score berechnen
            dice = dice_score(mask_png, segmentation)
            logging.info(f"{mask_filename}: Dice Score = {dice:.4f}")
            return mask_filename, dice
        except Exception as e:
            logging.error(f"Fehler beim Verarbeiten von {mask_filename}: {e}")
            return None
    else:
        logging.warning(f"Segmentationsdatei für {mask_filename} nicht gefunden!")
        return None

# Parallelisierte Verarbeitung
dice_scores = []
with ThreadPoolExecutor() as executor:
    futures = [executor.submit(process_single_file, mask_filename) for mask_filename in os.listdir(mask_png_folder) if mask_filename.endswith(".png")]
    dice_scores = [future.result() for future in futures if future.result() is not None]
# Out:
# 2025-09-08 11:43:24,310 - INFO - spleen_3_slice_08_segmentation.png: Dice Score = 0.9638
# 2025-09-08 11:43:24,321 - INFO - spleen_3_slice_06_segmentation.png: Dice Score = 0.9390
# 2025-09-08 11:43:24,340 - INFO - spleen_3_slice_05_segmentation.png: Dice Score = 0.9352
# 2025-09-08 11:43:24,386 - INFO - spleen_3_slice_01_segmentation.png: Dice Score = 0.5340
# 2025-09-08 11:43:24,393 - INFO - spleen_3_slice_09_segmentation.png: Dice Score = 0.9645
# 2025-09-08 11:43:24,400 - INFO - spleen_3_slice_02_segmentation.png: Dice Score = 0.9041
# 2025-09-08 11:43:24,393 - INFO - spleen_3_slice_07_segmentation.png: Dice Score = 0.8873
# 2025-09-08 11:43:24,432 - INFO - spleen_3_slice_03_segmentation.png: Dice Score = 0.9081
# 2025-09-08 11:43:24,447 - INFO - spleen_3_slice_12_segmentation.png: Dice Score = 0.9442
# 2025-09-08 11:43:24,452 - INFO - spleen_3_slice_10_segmentation.png: Dice Score = 0.9583
# 2025-09-08 11:43:24,467 - INFO - spleen_3_slice_04_segmentation.png: Dice Score = 0.9203
# 2025-09-08 11:43:24,486 - INFO - spleen_3_slice_11_segmentation.png: Dice Score = 0.9536
# 2025-09-08 11:43:24,503 - INFO - spleen_3_slice_13_segmentation.png: Dice Score = 0.8584
# 2025-09-08 11:43:24,582 - INFO - spleen_3_slice_14_segmentation.png: Dice Score = 0.8239
# 2025-09-08 11:43:24,609 - INFO - spleen_8_slice_04_segmentation.png: Dice Score = 0.9494
# 2025-09-08 11:43:24,611 - INFO - spleen_8_slice_03_segmentation.png: Dice Score = 0.9402
# 2025-09-08 11:43:24,666 - INFO - spleen_8_slice_05_segmentation.png: Dice Score = 0.9485
# 2025-09-08 11:43:24,682 - INFO - spleen_8_slice_01_segmentation.png: Dice Score = 0.8481
# 2025-09-08 11:43:24,695 - INFO - spleen_8_slice_06_segmentation.png: Dice Score = 0.9442
# 2025-09-08 11:43:24,700 - INFO - spleen_8_slice_08_segmentation.png: Dice Score = 0.9602
# 2025-09-08 11:43:24,742 - INFO - spleen_8_slice_07_segmentation.png: Dice Score = 0.9530
# 2025-09-08 11:43:24,746 - INFO - spleen_8_slice_10_segmentation.png: Dice Score = 0.9609
# 2025-09-08 11:43:24,749 - INFO - spleen_8_slice_09_segmentation.png: Dice Score = 0.9565
# 2025-09-08 11:43:24,749 - INFO - spleen_8_slice_02_segmentation.png: Dice Score = 0.9328
# 2025-09-08 11:43:24,865 - INFO - spleen_8_slice_18_segmentation.png: Dice Score = 0.9235
# 2025-09-08 11:43:24,882 - INFO - spleen_8_slice_12_segmentation.png: Dice Score = 0.9656
# 2025-09-08 11:43:24,882 - INFO - spleen_8_slice_16_segmentation.png: Dice Score = 0.9545
# 2025-09-08 11:43:24,882 - INFO - spleen_8_slice_15_segmentation.png: Dice Score = 0.9386
# 2025-09-08 11:43:24,899 - INFO - spleen_8_slice_17_segmentation.png: Dice Score = 0.9556
# 2025-09-08 11:43:24,899 - INFO - spleen_8_slice_13_segmentation.png: Dice Score = 0.9666
# 2025-09-08 11:43:24,916 - INFO - spleen_8_slice_14_segmentation.png: Dice Score = 0.9653
# 2025-09-08 11:43:25,032 - INFO - spleen_8_slice_11_segmentation.png: Dice Score = 0.9663
# 2025-09-08 11:43:25,049 - INFO - spleen_10_slice_06_segmentation.png: Dice Score = 0.9426
# 2025-09-08 11:43:25,049 - INFO - spleen_10_slice_04_segmentation.png: Dice Score = 0.9300
# 2025-09-08 11:43:25,049 - INFO - spleen_10_slice_01_segmentation.png: Dice Score = 0.7437
# 2025-09-08 11:43:25,032 - INFO - spleen_8_slice_19_segmentation.png: Dice Score = 0.8630
# 2025-09-08 11:43:25,065 - INFO - spleen_10_slice_05_segmentation.png: Dice Score = 0.8951
# 2025-09-08 11:43:25,148 - INFO - spleen_10_slice_02_segmentation.png: Dice Score = 0.8643
# 2025-09-08 11:43:25,148 - INFO - spleen_10_slice_03_segmentation.png: Dice Score = 0.9181
# 2025-09-08 11:43:25,188 - INFO - spleen_10_slice_07_segmentation.png: Dice Score = 0.9283
# 2025-09-08 11:43:25,192 - INFO - spleen_10_slice_09_segmentation.png: Dice Score = 0.9496
# 2025-09-08 11:43:25,206 - INFO - spleen_10_slice_11_segmentation.png: Dice Score = 0.9491
# 2025-09-08 11:43:25,215 - INFO - spleen_10_slice_08_segmentation.png: Dice Score = 0.9533
# 2025-09-08 11:43:25,267 - INFO - spleen_10_slice_12_segmentation.png: Dice Score = 0.8938
# 2025-09-08 11:43:25,306 - INFO - spleen_10_slice_13_segmentation.png: Dice Score = 0.8982
# 2025-09-08 11:43:25,316 - INFO - spleen_10_slice_15_segmentation.png: Dice Score = 0.8612
# 2025-09-08 11:43:25,337 - INFO - spleen_10_slice_16_segmentation.png: Dice Score = 0.8766
# 2025-09-08 11:43:25,352 - INFO - spleen_10_slice_17_segmentation.png: Dice Score = 0.8385
# 2025-09-08 11:43:25,359 - INFO - spleen_9_slice_01_segmentation.png: Dice Score = 0.8047
# 2025-09-08 11:43:25,377 - INFO - spleen_9_slice_03_segmentation.png: Dice Score = 0.9244
# 2025-09-08 11:43:25,435 - INFO - spleen_10_slice_14_segmentation.png: Dice Score = 0.9121
# 2025-09-08 11:43:25,455 - INFO - spleen_9_slice_06_segmentation.png: Dice Score = 0.9429
# 2025-09-08 11:43:25,459 - INFO - spleen_10_slice_10_segmentation.png: Dice Score = 0.9501
# 2025-09-08 11:43:25,458 - INFO - spleen_9_slice_07_segmentation.png: Dice Score = 0.9448
# 2025-09-08 11:43:25,457 - INFO - spleen_9_slice_02_segmentation.png: Dice Score = 0.9043
# 2025-09-08 11:43:25,514 - INFO - spleen_9_slice_05_segmentation.png: Dice Score = 0.9394
# 2025-09-08 11:43:25,522 - INFO - spleen_9_slice_04_segmentation.png: Dice Score = 0.9335
# 2025-09-08 11:43:25,582 - INFO - spleen_9_slice_09_segmentation.png: Dice Score = 0.9510
# 2025-09-08 11:43:25,601 - INFO - spleen_9_slice_08_segmentation.png: Dice Score = 0.9466
# 2025-09-08 11:43:25,649 - INFO - spleen_9_slice_12_segmentation.png: Dice Score = 0.9542
# 2025-09-08 11:43:25,651 - INFO - spleen_9_slice_13_segmentation.png: Dice Score = 0.9460
# 2025-09-08 11:43:25,662 - INFO - spleen_9_slice_10_segmentation.png: Dice Score = 0.9489
# 2025-09-08 11:43:25,717 - INFO - spleen_9_slice_14_segmentation.png: Dice Score = 0.9449
# 2025-09-08 11:43:25,728 - INFO - spleen_9_slice_11_segmentation.png: Dice Score = 0.9522
# 2025-09-08 11:43:25,769 - INFO - spleen_9_slice_20_segmentation.png: Dice Score = 0.9541
# 2025-09-08 11:43:25,763 - INFO - spleen_9_slice_19_segmentation.png: Dice Score = 0.9495
# 2025-09-08 11:43:25,774 - INFO - spleen_9_slice_16_segmentation.png: Dice Score = 0.9629
# 2025-09-08 11:43:25,849 - INFO - spleen_9_slice_21_segmentation.png: Dice Score = 0.9371
# 2025-09-08 11:43:25,855 - INFO - spleen_9_slice_18_segmentation.png: Dice Score = 0.9587
# 2025-09-08 11:43:25,865 - INFO - spleen_9_slice_17_segmentation.png: Dice Score = 0.9625
# 2025-09-08 11:43:25,871 - INFO - spleen_9_slice_15_segmentation.png: Dice Score = 0.9585
# 2025-09-08 11:43:25,882 - INFO - spleen_9_slice_24_segmentation.png: Dice Score = 0.9009
# 2025-09-08 11:43:25,896 - INFO - spleen_9_slice_23_segmentation.png: Dice Score = 0.9144
# 2025-09-08 11:43:25,931 - INFO - spleen_9_slice_25_segmentation.png: Dice Score = 0.8616
# 2025-09-08 11:43:25,981 - INFO - spleen_2_slice_02_segmentation.png: Dice Score = 0.9155
# 2025-09-08 11:43:26,053 - INFO - spleen_9_slice_22_segmentation.png: Dice Score = 0.8899
# 2025-09-08 11:43:26,040 - INFO - spleen_2_slice_03_segmentation.png: Dice Score = 0.9289
# 2025-09-08 11:43:26,015 - INFO - spleen_2_slice_01_segmentation.png: Dice Score = 0.7957
# 2025-09-08 11:43:26,080 - INFO - spleen_2_slice_05_segmentation.png: Dice Score = 0.9253
# 2025-09-08 11:43:26,181 - INFO - spleen_2_slice_07_segmentation.png: Dice Score = 0.9410
# 2025-09-08 11:43:26,213 - INFO - spleen_2_slice_08_segmentation.png: Dice Score = 0.8822
# 2025-09-08 11:43:26,181 - INFO - spleen_2_slice_04_segmentation.png: Dice Score = 0.9166
# 2025-09-08 11:43:26,198 - INFO - spleen_2_slice_06_segmentation.png: Dice Score = 0.9422
# 2025-09-08 11:43:26,181 - INFO - spleen_2_slice_11_segmentation.png: Dice Score = 0.9374
# 2025-09-08 11:43:26,280 - INFO - spleen_2_slice_10_segmentation.png: Dice Score = 0.9489
# 2025-09-08 11:43:26,331 - INFO - spleen_2_slice_16_segmentation.png: Dice Score = 0.9261
# 2025-09-08 11:43:26,364 - INFO - spleen_2_slice_12_segmentation.png: Dice Score = 0.9417
# 2025-09-08 11:43:26,364 - INFO - spleen_2_slice_09_segmentation.png: Dice Score = 0.9190
# 2025-09-08 11:43:26,397 - INFO - spleen_2_slice_15_segmentation.png: Dice Score = 0.9329
# 2025-09-08 11:43:26,397 - INFO - spleen_2_slice_13_segmentation.png: Dice Score = 0.9578
# 2025-09-08 11:43:26,397 - INFO - spleen_2_slice_14_segmentation.png: Dice Score = 0.9397
# 2025-09-08 11:43:26,431 - INFO - spleen_2_slice_19_segmentation.png: Dice Score = 0.8796
# 2025-09-08 11:43:26,514 - INFO - spleen_13_slice_03_segmentation.png: Dice Score = 0.8725
# 2025-09-08 11:43:26,448 - INFO - spleen_2_slice_17_segmentation.png: Dice Score = 0.8980
# 2025-09-08 11:43:26,531 - INFO - spleen_13_slice_05_segmentation.png: Dice Score = 0.9426
# 2025-09-08 11:43:26,448 - INFO - spleen_2_slice_18_segmentation.png: Dice Score = 0.8918
# 2025-09-08 11:43:26,547 - INFO - spleen_13_slice_02_segmentation.png: Dice Score = 0.4392
# 2025-09-08 11:43:26,547 - INFO - spleen_13_slice_04_segmentation.png: Dice Score = 0.9295
# 2025-09-08 11:43:26,564 - INFO - spleen_2_slice_20_segmentation.png: Dice Score = 0.8486
# 2025-09-08 11:43:26,682 - INFO - spleen_13_slice_01_segmentation.png: Dice Score = 0.7425
# 2025-09-08 11:43:26,702 - INFO - spleen_13_slice_06_segmentation.png: Dice Score = 0.9452
# 2025-09-08 11:43:26,715 - INFO - spleen_13_slice_07_segmentation.png: Dice Score = 0.9493
# 2025-09-08 11:43:26,769 - INFO - spleen_13_slice_09_segmentation.png: Dice Score = 0.9438
# 2025-09-08 11:43:26,781 - INFO - spleen_13_slice_10_segmentation.png: Dice Score = 0.9393
# 2025-09-08 11:43:26,789 - INFO - spleen_13_slice_11_segmentation.png: Dice Score = 0.9415
# 2025-09-08 11:43:26,832 - INFO - spleen_13_slice_15_segmentation.png: Dice Score = 0.9381
# 2025-09-08 11:43:26,845 - INFO - spleen_13_slice_08_segmentation.png: Dice Score = 0.9493
# 2025-09-08 11:43:26,866 - INFO - spleen_13_slice_14_segmentation.png: Dice Score = 0.9462
# 2025-09-08 11:43:26,937 - INFO - spleen_13_slice_12_segmentation.png: Dice Score = 0.9416
# 2025-09-08 11:43:26,941 - INFO - spleen_13_slice_18_segmentation.png: Dice Score = 0.9420
# 2025-09-08 11:43:26,967 - INFO - spleen_13_slice_17_segmentation.png: Dice Score = 0.9490
# 2025-09-08 11:43:26,957 - INFO - spleen_13_slice_16_segmentation.png: Dice Score = 0.9517
# 2025-09-08 11:43:27,000 - INFO - spleen_13_slice_19_segmentation.png: Dice Score = 0.9127
# 2025-09-08 11:43:26,970 - INFO - spleen_13_slice_20_segmentation.png: Dice Score = 0.9113
# 2025-09-08 11:43:26,970 - INFO - spleen_13_slice_13_segmentation.png: Dice Score = 0.9375
# 2025-09-08 11:43:27,047 - INFO - spleen_13_slice_22_segmentation.png: Dice Score = 0.9515
# 2025-09-08 11:43:27,063 - INFO - spleen_13_slice_21_segmentation.png: Dice Score = 0.9461
# 2025-09-08 11:43:27,078 - INFO - spleen_13_slice_23_segmentation.png: Dice Score = 0.9538
# 2025-09-08 11:43:27,094 - INFO - spleen_13_slice_24_segmentation.png: Dice Score = 0.9484
# 2025-09-08 11:43:27,117 - INFO - spleen_13_slice_27_segmentation.png: Dice Score = 0.9622
# 2025-09-08 11:43:27,094 - INFO - spleen_13_slice_25_segmentation.png: Dice Score = 0.9479
# 2025-09-08 11:43:27,180 - INFO - spleen_13_slice_29_segmentation.png: Dice Score = 0.9677
# 2025-09-08 11:43:27,185 - INFO - spleen_13_slice_26_segmentation.png: Dice Score = 0.9572
# 2025-09-08 11:43:27,194 - INFO - spleen_13_slice_28_segmentation.png: Dice Score = 0.9633
# 2025-09-08 11:43:27,215 - INFO - spleen_13_slice_32_segmentation.png: Dice Score = 0.9540
# 2025-09-08 11:43:27,262 - INFO - spleen_13_slice_34_segmentation.png: Dice Score = 0.9334
# 2025-09-08 11:43:27,292 - INFO - spleen_13_slice_31_segmentation.png: Dice Score = 0.9638
# 2025-09-08 11:43:27,300 - INFO - spleen_13_slice_33_segmentation.png: Dice Score = 0.9337
# 2025-09-08 11:43:27,311 - INFO - spleen_13_slice_35_segmentation.png: Dice Score = 0.9170
# 2025-09-08 11:43:27,313 - INFO - spleen_13_slice_36_segmentation.png: Dice Score = 0.8937
# 2025-09-08 11:43:27,347 - INFO - spleen_13_slice_37_segmentation.png: Dice Score = 0.8806
# 2025-09-08 11:43:27,394 - INFO - spleen_13_slice_38_segmentation.png: Dice Score = 0.8893
# 2025-09-08 11:43:27,409 - INFO - spleen_13_slice_39_segmentation.png: Dice Score = 0.8862
# 2025-09-08 11:43:27,436 - INFO - spleen_14_slice_02_segmentation.png: Dice Score = 0.9168
# 2025-09-08 11:43:27,457 - INFO - spleen_14_slice_01_segmentation.png: Dice Score = 0.7426
# 2025-09-08 11:43:27,479 - INFO - spleen_14_slice_04_segmentation.png: Dice Score = 0.8897
# 2025-09-08 11:43:27,494 - INFO - spleen_13_slice_30_segmentation.png: Dice Score = 0.9678
# 2025-09-08 11:43:27,525 - INFO - spleen_14_slice_06_segmentation.png: Dice Score = 0.9387
# 2025-09-08 11:43:27,553 - INFO - spleen_14_slice_05_segmentation.png: Dice Score = 0.9297
# 2025-09-08 11:43:27,570 - INFO - spleen_14_slice_07_segmentation.png: Dice Score = 0.9238
# 2025-09-08 11:43:27,596 - INFO - spleen_14_slice_09_segmentation.png: Dice Score = 0.8995
# 2025-09-08 11:43:27,680 - INFO - spleen_14_slice_10_segmentation.png: Dice Score = 0.9362
# 2025-09-08 11:43:27,730 - INFO - spleen_14_slice_13_segmentation.png: Dice Score = 0.9299
# 2025-09-08 11:43:27,730 - INFO - spleen_14_slice_11_segmentation.png: Dice Score = 0.9194
# 2025-09-08 11:43:27,647 - INFO - spleen_14_slice_03_segmentation.png: Dice Score = 0.8936
# 2025-09-08 11:43:27,780 - INFO - spleen_14_slice_08_segmentation.png: Dice Score = 0.8270
# 2025-09-08 11:43:27,763 - INFO - spleen_13_slice_40_segmentation.png: Dice Score = 0.6964
# 2025-09-08 11:43:27,763 - INFO - spleen_14_slice_15_segmentation.png: Dice Score = 0.9363
# 2025-09-08 11:43:27,747 - INFO - spleen_14_slice_14_segmentation.png: Dice Score = 0.9503
# 2025-09-08 11:43:27,886 - INFO - spleen_14_slice_18_segmentation.png: Dice Score = 0.9215
# 2025-09-08 11:43:27,908 - INFO - spleen_14_slice_12_segmentation.png: Dice Score = 0.9056
# 2025-09-08 11:43:27,909 - INFO - spleen_14_slice_16_segmentation.png: Dice Score = 0.9523
# 2025-09-08 11:43:27,931 - INFO - spleen_14_slice_17_segmentation.png: Dice Score = 0.9493
# 2025-09-08 11:43:27,964 - INFO - spleen_14_slice_20_segmentation.png: Dice Score = 0.9101
# 2025-09-08 11:43:27,981 - INFO - spleen_14_slice_19_segmentation.png: Dice Score = 0.8992
# 2025-09-08 11:43:27,971 - INFO - spleen_16_slice_01_segmentation.png: Dice Score = 0.8398
# 2025-09-08 11:43:27,979 - INFO - spleen_16_slice_02_segmentation.png: Dice Score = 0.8845
# 2025-09-08 11:43:27,967 - INFO - spleen_14_slice_21_segmentation.png: Dice Score = 0.8649
# 2025-09-08 11:43:28,054 - INFO - spleen_16_slice_06_segmentation.png: Dice Score = 0.9564
# 2025-09-08 11:43:28,073 - INFO - spleen_16_slice_04_segmentation.png: Dice Score = 0.9286
# 2025-09-08 11:43:28,096 - INFO - spleen_16_slice_10_segmentation.png: Dice Score = 0.8905
# 2025-09-08 11:43:28,111 - INFO - spleen_16_slice_05_segmentation.png: Dice Score = 0.9397
# 2025-09-08 11:43:28,120 - INFO - spleen_16_slice_09_segmentation.png: Dice Score = 0.9109
# 2025-09-08 11:43:28,123 - INFO - spleen_16_slice_08_segmentation.png: Dice Score = 0.9333
# 2025-09-08 11:43:28,127 - INFO - spleen_16_slice_03_segmentation.png: Dice Score = 0.8538
# 2025-09-08 11:43:28,147 - INFO - spleen_16_slice_11_segmentation.png: Dice Score = 0.7865
# 2025-09-08 11:43:28,194 - INFO - spleen_6_slice_01_segmentation.png: Dice Score = 0.7740
# 2025-09-08 11:43:28,194 - INFO - spleen_16_slice_07_segmentation.png: Dice Score = 0.9516
# 2025-09-08 11:43:28,278 - INFO - spleen_6_slice_02_segmentation.png: Dice Score = 0.7714
# 2025-09-08 11:43:28,279 - INFO - spleen_6_slice_03_segmentation.png: Dice Score = 0.8501
# 2025-09-08 11:43:28,313 - INFO - spleen_6_slice_04_segmentation.png: Dice Score = 0.8908
# 2025-09-08 11:43:28,329 - INFO - spleen_6_slice_05_segmentation.png: Dice Score = 0.9117
# 2025-09-08 11:43:28,329 - INFO - spleen_6_slice_06_segmentation.png: Dice Score = 0.8951
# 2025-09-08 11:43:28,364 - INFO - spleen_6_slice_08_segmentation.png: Dice Score = 0.9158
# 2025-09-08 11:43:28,409 - INFO - spleen_6_slice_09_segmentation.png: Dice Score = 0.9338
# 2025-09-08 11:43:28,427 - INFO - spleen_6_slice_11_segmentation.png: Dice Score = 0.9428
# 2025-09-08 11:43:28,450 - INFO - spleen_6_slice_14_segmentation.png: Dice Score = 0.9449
# 2025-09-08 11:43:28,435 - INFO - spleen_6_slice_10_segmentation.png: Dice Score = 0.9418
# 2025-09-08 11:43:28,435 - INFO - spleen_6_slice_13_segmentation.png: Dice Score = 0.9425
# 2025-09-08 11:43:28,454 - INFO - spleen_6_slice_12_segmentation.png: Dice Score = 0.9424
# 2025-09-08 11:43:28,479 - INFO - spleen_6_slice_15_segmentation.png: Dice Score = 0.9432
# 2025-09-08 11:43:28,499 - INFO - spleen_6_slice_07_segmentation.png: Dice Score = 0.8977
# 2025-09-08 11:43:28,539 - INFO - spleen_6_slice_21_segmentation.png: Dice Score = 0.9405
# 2025-09-08 11:43:28,548 - INFO - spleen_6_slice_20_segmentation.png: Dice Score = 0.9387
# 2025-09-08 11:43:28,562 - INFO - spleen_6_slice_16_segmentation.png: Dice Score = 0.9388
# 2025-09-08 11:43:28,598 - INFO - spleen_6_slice_18_segmentation.png: Dice Score = 0.9313
# 2025-09-08 11:43:28,619 - INFO - spleen_6_slice_22_segmentation.png: Dice Score = 0.9414
# 2025-09-08 11:43:28,646 - INFO - spleen_6_slice_24_segmentation.png: Dice Score = 0.9354
# 2025-09-08 11:43:28,648 - INFO - spleen_6_slice_25_segmentation.png: Dice Score = 0.9253
# 2025-09-08 11:43:28,687 - INFO - spleen_6_slice_23_segmentation.png: Dice Score = 0.9415
# 2025-09-08 11:43:28,688 - INFO - spleen_6_slice_27_segmentation.png: Dice Score = 0.9298
# 2025-09-08 11:43:28,722 - INFO - spleen_6_slice_28_segmentation.png: Dice Score = 0.9301
# 2025-09-08 11:43:28,748 - INFO - spleen_6_slice_17_segmentation.png: Dice Score = 0.9397
# 2025-09-08 11:43:28,781 - INFO - spleen_6_slice_32_segmentation.png: Dice Score = 0.9302
# 2025-09-08 11:43:28,781 - INFO - spleen_6_slice_29_segmentation.png: Dice Score = 0.9309
# 2025-09-08 11:43:28,781 - INFO - spleen_6_slice_31_segmentation.png: Dice Score = 0.9216
# 2025-09-08 11:43:28,867 - INFO - spleen_6_slice_34_segmentation.png: Dice Score = 0.9525
# 2025-09-08 11:43:28,872 - INFO - spleen_6_slice_35_segmentation.png: Dice Score = 0.9454
# 2025-09-08 11:43:28,874 - INFO - spleen_6_slice_26_segmentation.png: Dice Score = 0.9301
# 2025-09-08 11:43:28,879 - INFO - spleen_6_slice_37_segmentation.png: Dice Score = 0.9391
# 2025-09-08 11:43:28,943 - INFO - spleen_6_slice_36_segmentation.png: Dice Score = 0.9417
# 2025-09-08 11:43:28,957 - INFO - spleen_6_slice_19_segmentation.png: Dice Score = 0.9396
# 2025-09-08 11:43:28,983 - INFO - spleen_6_slice_38_segmentation.png: Dice Score = 0.9350
# 2025-09-08 11:43:28,997 - INFO - spleen_6_slice_30_segmentation.png: Dice Score = 0.9266
# 2025-09-08 11:43:28,995 - INFO - spleen_6_slice_41_segmentation.png: Dice Score = 0.9402
# 2025-09-08 11:43:28,995 - INFO - spleen_6_slice_33_segmentation.png: Dice Score = 0.9386
# 2025-09-08 11:43:29,008 - INFO - spleen_6_slice_39_segmentation.png: Dice Score = 0.9384
# 2025-09-08 11:43:29,035 - INFO - spleen_6_slice_42_segmentation.png: Dice Score = 0.9409
# 2025-09-08 11:43:29,126 - INFO - spleen_6_slice_44_segmentation.png: Dice Score = 0.9412
# 2025-09-08 11:43:29,127 - INFO - spleen_6_slice_43_segmentation.png: Dice Score = 0.9452
# 2025-09-08 11:43:29,063 - INFO - spleen_6_slice_40_segmentation.png: Dice Score = 0.9345
# 2025-09-08 11:43:29,178 - INFO - spleen_6_slice_45_segmentation.png: Dice Score = 0.9430
# 2025-09-08 11:43:29,178 - INFO - spleen_6_slice_47_segmentation.png: Dice Score = 0.9389
# 2025-09-08 11:43:29,195 - INFO - spleen_6_slice_46_segmentation.png: Dice Score = 0.9410
# 2025-09-08 11:43:29,211 - INFO - spleen_6_slice_48_segmentation.png: Dice Score = 0.9393
# 2025-09-08 11:43:29,245 - INFO - spleen_6_slice_53_segmentation.png: Dice Score = 0.8632
# 2025-09-08 11:43:29,227 - INFO - spleen_6_slice_49_segmentation.png: Dice Score = 0.9375
# 2025-09-08 11:43:29,311 - INFO - spleen_6_slice_55_segmentation.png: Dice Score = 0.8693
# 2025-09-08 11:43:29,311 - INFO - spleen_6_slice_50_segmentation.png: Dice Score = 0.9201
# 2025-09-08 11:43:29,311 - INFO - spleen_6_slice_51_segmentation.png: Dice Score = 0.8614
# 2025-09-08 11:43:29,328 - INFO - spleen_6_slice_54_segmentation.png: Dice Score = 0.8568
# 2025-09-08 11:43:29,345 - INFO - spleen_6_slice_56_segmentation.png: Dice Score = 0.8585
# 2025-09-08 11:43:29,345 - INFO - spleen_6_slice_52_segmentation.png: Dice Score = 0.8793
# 2025-09-08 11:43:29,428 - INFO - spleen_17_slice_04_segmentation.png: Dice Score = 0.9045
# 2025-09-08 11:43:29,471 - INFO - spleen_17_slice_01_segmentation.png: Dice Score = 0.8389
# 2025-09-08 11:43:29,461 - INFO - spleen_6_slice_57_segmentation.png: Dice Score = 0.8475
# 2025-09-08 11:43:29,445 - INFO - spleen_17_slice_05_segmentation.png: Dice Score = 0.8994
# 2025-09-08 11:43:29,529 - INFO - spleen_17_slice_02_segmentation.png: Dice Score = 0.9029
# 2025-09-08 11:43:29,589 - INFO - spleen_17_slice_08_segmentation.png: Dice Score = 0.9349
# 2025-09-08 11:43:29,591 - INFO - spleen_17_slice_10_segmentation.png: Dice Score = 0.9295
# 2025-09-08 11:43:29,593 - INFO - spleen_17_slice_07_segmentation.png: Dice Score = 0.9445
# 2025-09-08 11:43:29,611 - INFO - spleen_17_slice_09_segmentation.png: Dice Score = 0.8330
# 2025-09-08 11:43:29,650 - INFO - spleen_17_slice_03_segmentation.png: Dice Score = 0.9186
# 2025-09-08 11:43:29,662 - INFO - spleen_6_slice_58_segmentation.png: Dice Score = 0.7930
# 2025-09-08 11:43:29,675 - INFO - spleen_17_slice_06_segmentation.png: Dice Score = 0.9354
# 2025-09-08 11:43:29,727 - INFO - spleen_17_slice_11_segmentation.png: Dice Score = 0.9414
# 2025-09-08 11:43:29,744 - INFO - spleen_17_slice_14_segmentation.png: Dice Score = 0.9508
# 2025-09-08 11:43:29,778 - INFO - spleen_17_slice_18_segmentation.png: Dice Score = 0.9516
# 2025-09-08 11:43:29,910 - INFO - spleen_17_slice_21_segmentation.png: Dice Score = 0.9562
# 2025-09-08 11:43:29,919 - INFO - spleen_17_slice_20_segmentation.png: Dice Score = 0.9607
# 2025-09-08 11:43:29,941 - INFO - spleen_17_slice_16_segmentation.png: Dice Score = 0.9532
# 2025-09-08 11:43:29,956 - INFO - spleen_17_slice_19_segmentation.png: Dice Score = 0.9470
# 2025-09-08 11:43:29,970 - INFO - spleen_17_slice_12_segmentation.png: Dice Score = 0.9512
# 2025-09-08 11:43:29,981 - INFO - spleen_17_slice_13_segmentation.png: Dice Score = 0.9540
# 2025-09-08 11:43:29,986 - INFO - spleen_17_slice_15_segmentation.png: Dice Score = 0.9510
# 2025-09-08 11:43:30,063 - INFO - spleen_17_slice_23_segmentation.png: Dice Score = 0.9431
# 2025-09-08 11:43:30,065 - INFO - spleen_17_slice_22_segmentation.png: Dice Score = 0.9584
# 2025-09-08 11:43:30,111 - INFO - spleen_17_slice_25_segmentation.png: Dice Score = 0.9283
# 2025-09-08 11:43:30,123 - INFO - spleen_17_slice_26_segmentation.png: Dice Score = 0.9344
# 2025-09-08 11:43:30,123 - INFO - spleen_17_slice_17_segmentation.png: Dice Score = 0.9538
# 2025-09-08 11:43:30,129 - INFO - spleen_17_slice_27_segmentation.png: Dice Score = 0.9410
# 2025-09-08 11:43:30,157 - INFO - spleen_17_slice_28_segmentation.png: Dice Score = 0.9064
# 2025-09-08 11:43:30,170 - INFO - spleen_17_slice_24_segmentation.png: Dice Score = 0.9342
# 2025-09-08 11:43:30,201 - INFO - spleen_19_slice_01_segmentation.png: Dice Score = 0.8523
# 2025-09-08 11:43:30,210 - INFO - spleen_19_slice_02_segmentation.png: Dice Score = 0.9263
# 2025-09-08 11:43:30,224 - INFO - spleen_19_slice_04_segmentation.png: Dice Score = 0.9534
# 2025-09-08 11:43:30,227 - INFO - spleen_19_slice_03_segmentation.png: Dice Score = 0.9312
# 2025-09-08 11:43:30,282 - INFO - spleen_19_slice_06_segmentation.png: Dice Score = 0.9619
# 2025-09-08 11:43:30,283 - INFO - spleen_19_slice_05_segmentation.png: Dice Score = 0.9598
# 2025-09-08 11:43:30,285 - INFO - spleen_19_slice_08_segmentation.png: Dice Score = 0.9562
# 2025-09-08 11:43:30,307 - INFO - spleen_19_slice_11_segmentation.png: Dice Score = 0.9602
# 2025-09-08 11:43:30,372 - INFO - spleen_19_slice_14_segmentation.png: Dice Score = 0.9578
# 2025-09-08 11:43:30,373 - INFO - spleen_19_slice_12_segmentation.png: Dice Score = 0.9497
# 2025-09-08 11:43:30,446 - INFO - spleen_19_slice_15_segmentation.png: Dice Score = 0.9126
# 2025-09-08 11:43:30,482 - INFO - spleen_19_slice_07_segmentation.png: Dice Score = 0.9583
# 2025-09-08 11:43:30,486 - INFO - spleen_19_slice_17_segmentation.png: Dice Score = 0.8889
# 2025-09-08 11:43:30,490 - INFO - spleen_19_slice_13_segmentation.png: Dice Score = 0.9548
# 2025-09-08 11:43:30,506 - INFO - spleen_19_slice_18_segmentation.png: Dice Score = 0.8724
# 2025-09-08 11:43:30,550 - INFO - spleen_19_slice_16_segmentation.png: Dice Score = 0.9208
# 2025-09-08 11:43:30,567 - INFO - spleen_19_slice_10_segmentation.png: Dice Score = 0.9617
# 2025-09-08 11:43:30,624 - INFO - spleen_19_slice_09_segmentation.png: Dice Score = 0.9596
# 2025-09-08 11:43:30,629 - INFO - spleen_12_slice_02_segmentation.png: Dice Score = 0.8517
# 2025-09-08 11:43:30,634 - INFO - spleen_12_slice_01_segmentation.png: Dice Score = 0.7939
# 2025-09-08 11:43:30,645 - INFO - spleen_12_slice_04_segmentation.png: Dice Score = 0.9038
# 2025-09-08 11:43:30,670 - INFO - spleen_12_slice_06_segmentation.png: Dice Score = 0.9199
# 2025-09-08 11:43:30,712 - INFO - spleen_12_slice_07_segmentation.png: Dice Score = 0.9172
# 2025-09-08 11:43:30,733 - INFO - spleen_12_slice_03_segmentation.png: Dice Score = 0.8867
# 2025-09-08 11:43:30,786 - INFO - spleen_12_slice_08_segmentation.png: Dice Score = 0.9186
# 2025-09-08 11:43:30,814 - INFO - spleen_12_slice_12_segmentation.png: Dice Score = 0.9387
# 2025-09-08 11:43:30,833 - INFO - spleen_12_slice_11_segmentation.png: Dice Score = 0.9353
# 2025-09-08 11:43:30,836 - INFO - spleen_12_slice_10_segmentation.png: Dice Score = 0.9282
# 2025-09-08 11:43:30,838 - INFO - spleen_12_slice_05_segmentation.png: Dice Score = 0.9072
# 2025-09-08 11:43:30,885 - INFO - spleen_12_slice_13_segmentation.png: Dice Score = 0.9400
# 2025-09-08 11:43:30,901 - INFO - spleen_12_slice_09_segmentation.png: Dice Score = 0.9255
# 2025-09-08 11:43:30,962 - INFO - spleen_12_slice_15_segmentation.png: Dice Score = 0.9480
# 2025-09-08 11:43:30,963 - INFO - spleen_12_slice_18_segmentation.png: Dice Score = 0.9437
# 2025-09-08 11:43:30,966 - INFO - spleen_12_slice_19_segmentation.png: Dice Score = 0.9444
# 2025-09-08 11:43:30,989 - INFO - spleen_12_slice_21_segmentation.png: Dice Score = 0.9394
# 2025-09-08 11:43:31,026 - INFO - spleen_12_slice_14_segmentation.png: Dice Score = 0.9438
# 2025-09-08 11:43:31,066 - INFO - spleen_12_slice_22_segmentation.png: Dice Score = 0.9450
# 2025-09-08 11:43:31,087 - INFO - spleen_12_slice_24_segmentation.png: Dice Score = 0.9508
# 2025-09-08 11:43:31,098 - INFO - spleen_12_slice_17_segmentation.png: Dice Score = 0.9437
# 2025-09-08 11:43:31,138 - INFO - spleen_12_slice_23_segmentation.png: Dice Score = 0.9423
# 2025-09-08 11:43:31,164 - INFO - spleen_12_slice_26_segmentation.png: Dice Score = 0.9543
# 2025-09-08 11:43:31,178 - INFO - spleen_12_slice_25_segmentation.png: Dice Score = 0.9522
# 2025-09-08 11:43:31,192 - INFO - spleen_12_slice_16_segmentation.png: Dice Score = 0.9475
# 2025-09-08 11:43:31,226 - INFO - spleen_12_slice_29_segmentation.png: Dice Score = 0.9580
# 2025-09-08 11:43:31,235 - INFO - spleen_12_slice_20_segmentation.png: Dice Score = 0.9341
# 2025-09-08 11:43:31,299 - INFO - spleen_12_slice_27_segmentation.png: Dice Score = 0.9496
# 2025-09-08 11:43:31,312 - INFO - spleen_12_slice_32_segmentation.png: Dice Score = 0.9549
# 2025-09-08 11:43:31,329 - INFO - spleen_12_slice_31_segmentation.png: Dice Score = 0.9555
# 2025-09-08 11:43:31,355 - INFO - spleen_12_slice_35_segmentation.png: Dice Score = 0.9481
# 2025-09-08 11:43:31,372 - INFO - spleen_12_slice_30_segmentation.png: Dice Score = 0.9568
# 2025-09-08 11:43:31,383 - INFO - spleen_12_slice_28_segmentation.png: Dice Score = 0.9522
# 2025-09-08 11:43:31,549 - INFO - spleen_12_slice_41_segmentation.png: Dice Score = 0.9576
# 2025-09-08 11:43:31,550 - INFO - spleen_12_slice_40_segmentation.png: Dice Score = 0.9558
# 2025-09-08 11:43:31,562 - INFO - spleen_12_slice_34_segmentation.png: Dice Score = 0.9443
# 2025-09-08 11:43:31,589 - INFO - spleen_12_slice_33_segmentation.png: Dice Score = 0.9535
# 2025-09-08 11:43:31,590 - INFO - spleen_12_slice_37_segmentation.png: Dice Score = 0.9510
# 2025-09-08 11:43:31,591 - INFO - spleen_12_slice_36_segmentation.png: Dice Score = 0.9522
# 2025-09-08 11:43:31,603 - INFO - spleen_12_slice_39_segmentation.png: Dice Score = 0.9489
# 2025-09-08 11:43:31,690 - INFO - spleen_12_slice_42_segmentation.png: Dice Score = 0.9555
# 2025-09-08 11:43:31,698 - INFO - spleen_12_slice_45_segmentation.png: Dice Score = 0.9421
# 2025-09-08 11:43:31,708 - INFO - spleen_12_slice_43_segmentation.png: Dice Score = 0.9584
# 2025-09-08 11:43:31,722 - INFO - spleen_12_slice_48_segmentation.png: Dice Score = 0.9479
# 2025-09-08 11:43:31,770 - INFO - spleen_12_slice_38_segmentation.png: Dice Score = 0.9270
# 2025-09-08 11:43:31,819 - INFO - spleen_12_slice_50_segmentation.png: Dice Score = 0.9551
# 2025-09-08 11:43:31,845 - INFO - spleen_12_slice_46_segmentation.png: Dice Score = 0.9508
# 2025-09-08 11:43:31,853 - INFO - spleen_12_slice_52_segmentation.png: Dice Score = 0.9487
# 2025-09-08 11:43:31,923 - INFO - spleen_12_slice_44_segmentation.png: Dice Score = 0.9464
# 2025-09-08 11:43:31,925 - INFO - spleen_12_slice_53_segmentation.png: Dice Score = 0.9411
# 2025-09-08 11:43:31,996 - INFO - spleen_12_slice_55_segmentation.png: Dice Score = 0.9252
# 2025-09-08 11:43:32,002 - INFO - spleen_12_slice_51_segmentation.png: Dice Score = 0.9521
# 2025-09-08 11:43:32,019 - INFO - spleen_12_slice_56_segmentation.png: Dice Score = 0.9237
# 2025-09-08 11:43:32,063 - INFO - spleen_12_slice_47_segmentation.png: Dice Score = 0.9566
# 2025-09-08 11:43:32,070 - INFO - spleen_12_slice_49_segmentation.png: Dice Score = 0.9583
# 2025-09-08 11:43:32,100 - INFO - spleen_12_slice_58_segmentation.png: Dice Score = 0.9352
# 2025-09-08 11:43:32,100 - INFO - spleen_12_slice_57_segmentation.png: Dice Score = 0.9196
# 2025-09-08 11:43:32,120 - INFO - spleen_12_slice_54_segmentation.png: Dice Score = 0.9189
# 2025-09-08 11:43:32,133 - INFO - spleen_12_slice_60_segmentation.png: Dice Score = 0.9391
# 2025-09-08 11:43:32,153 - INFO - spleen_12_slice_59_segmentation.png: Dice Score = 0.9404
# 2025-09-08 11:43:32,169 - INFO - spleen_12_slice_61_segmentation.png: Dice Score = 0.9409
# 2025-09-08 11:43:32,225 - INFO - spleen_12_slice_64_segmentation.png: Dice Score = 0.9379
# 2025-09-08 11:43:32,292 - INFO - spleen_12_slice_66_segmentation.png: Dice Score = 0.9076
# 2025-09-08 11:43:32,296 - INFO - spleen_12_slice_67_segmentation.png: Dice Score = 0.9016
# 2025-09-08 11:43:32,348 - INFO - spleen_12_slice_65_segmentation.png: Dice Score = 0.9265
# 2025-09-08 11:43:32,351 - INFO - spleen_12_slice_68_segmentation.png: Dice Score = 0.8725
# 2025-09-08 11:43:32,353 - INFO - spleen_12_slice_69_segmentation.png: Dice Score = 0.8701
# 2025-09-08 11:43:32,397 - INFO - spleen_12_slice_70_segmentation.png: Dice Score = 0.8700
# 2025-09-08 11:43:32,403 - INFO - spleen_12_slice_63_segmentation.png: Dice Score = 0.9478
# 2025-09-08 11:43:32,414 - INFO - spleen_12_slice_62_segmentation.png: Dice Score = 0.9468
# 2025-09-08 11:43:32,431 - INFO - spleen_12_slice_71_segmentation.png: Dice Score = 0.8672
# 2025-09-08 11:43:32,444 - INFO - spleen_12_slice_72_segmentation.png: Dice Score = 0.8554
# 2025-09-08 11:43:32,452 - INFO - spleen_12_slice_73_segmentation.png: Dice Score = 0.8410
# 2025-09-08 11:43:32,505 - INFO - spleen_12_slice_75_segmentation.png: Dice Score = 0.8604
# 2025-09-08 11:43:32,516 - INFO - spleen_12_slice_74_segmentation.png: Dice Score = 0.8428
# 2025-09-08 11:43:32,567 - INFO - spleen_12_slice_76_segmentation.png: Dice Score = 0.8891
# 2025-09-08 11:43:32,568 - INFO - spleen_12_slice_77_segmentation.png: Dice Score = 0.8849
# 2025-09-08 11:43:32,597 - INFO - spleen_12_slice_79_segmentation.png: Dice Score = 0.8947
# 2025-09-08 11:43:32,603 - INFO - spleen_12_slice_78_segmentation.png: Dice Score = 0.8972
# 2025-09-08 11:43:32,624 - INFO - spleen_12_slice_80_segmentation.png: Dice Score = 0.8857
# 2025-09-08 11:43:32,649 - INFO - spleen_18_slice_02_segmentation.png: Dice Score = 0.8370
# 2025-09-08 11:43:32,655 - INFO - spleen_18_slice_01_segmentation.png: Dice Score = 0.7407
# 2025-09-08 11:43:32,678 - INFO - spleen_18_slice_03_segmentation.png: Dice Score = 0.8676
# 2025-09-08 11:43:32,703 - INFO - spleen_18_slice_05_segmentation.png: Dice Score = 0.8951
# 2025-09-08 11:43:32,750 - INFO - spleen_18_slice_08_segmentation.png: Dice Score = 0.9100
# 2025-09-08 11:43:32,754 - INFO - spleen_18_slice_06_segmentation.png: Dice Score = 0.8907
# 2025-09-08 11:43:32,785 - INFO - spleen_18_slice_09_segmentation.png: Dice Score = 0.9204
# 2025-09-08 11:43:32,787 - INFO - spleen_18_slice_10_segmentation.png: Dice Score = 0.9215
# 2025-09-08 11:43:32,815 - INFO - spleen_18_slice_11_segmentation.png: Dice Score = 0.9272
# 2025-09-08 11:43:32,865 - INFO - spleen_18_slice_07_segmentation.png: Dice Score = 0.9002
# 2025-09-08 11:43:32,877 - INFO - spleen_18_slice_13_segmentation.png: Dice Score = 0.9237
# 2025-09-08 11:43:32,885 - INFO - spleen_18_slice_04_segmentation.png: Dice Score = 0.8861
# 2025-09-08 11:43:32,908 - INFO - spleen_18_slice_12_segmentation.png: Dice Score = 0.9281
# 2025-09-08 11:43:32,916 - INFO - spleen_18_slice_15_segmentation.png: Dice Score = 0.9326
# 2025-09-08 11:43:32,917 - INFO - spleen_18_slice_16_segmentation.png: Dice Score = 0.9348
# 2025-09-08 11:43:32,931 - INFO - spleen_18_slice_17_segmentation.png: Dice Score = 0.9368
# 2025-09-08 11:43:32,972 - INFO - spleen_18_slice_20_segmentation.png: Dice Score = 0.9367
# 2025-09-08 11:43:33,013 - INFO - spleen_18_slice_21_segmentation.png: Dice Score = 0.9020
# 2025-09-08 11:43:33,029 - INFO - spleen_18_slice_23_segmentation.png: Dice Score = 0.8632
# 2025-09-08 11:43:33,064 - INFO - spleen_18_slice_24_segmentation.png: Dice Score = 0.8471
# 2025-09-08 11:43:33,113 - INFO - spleen_18_slice_14_segmentation.png: Dice Score = 0.9275
# 2025-09-08 11:43:33,161 - INFO - spleen_18_slice_19_segmentation.png: Dice Score = 0.9388
# 2025-09-08 11:43:33,287 - INFO - spleen_18_slice_29_segmentation.png: Dice Score = 0.9061
# 2025-09-08 11:43:33,288 - INFO - spleen_18_slice_28_segmentation.png: Dice Score = 0.8336
# 2025-09-08 11:43:33,304 - INFO - spleen_18_slice_18_segmentation.png: Dice Score = 0.9384
# 2025-09-08 11:43:33,318 - INFO - spleen_18_slice_26_segmentation.png: Dice Score = 0.8235
# 2025-09-08 11:43:33,341 - INFO - spleen_18_slice_30_segmentation.png: Dice Score = 0.9220
# 2025-09-08 11:43:33,342 - INFO - spleen_18_slice_27_segmentation.png: Dice Score = 0.8142
# 2025-09-08 11:43:33,371 - INFO - spleen_18_slice_25_segmentation.png: Dice Score = 0.8235
# 2025-09-08 11:43:33,433 - INFO - spleen_18_slice_22_segmentation.png: Dice Score = 0.8817
# 2025-09-08 11:43:33,484 - INFO - spleen_18_slice_31_segmentation.png: Dice Score = 0.9384
# 2025-09-08 11:43:33,496 - INFO - spleen_18_slice_36_segmentation.png: Dice Score = 0.9327
# 2025-09-08 11:43:33,506 - INFO - spleen_18_slice_37_segmentation.png: Dice Score = 0.9276
# 2025-09-08 11:43:33,513 - INFO - spleen_18_slice_33_segmentation.png: Dice Score = 0.9452
# 2025-09-08 11:43:33,510 - INFO - spleen_18_slice_34_segmentation.png: Dice Score = 0.9302
# 2025-09-08 11:43:33,515 - INFO - spleen_18_slice_38_segmentation.png: Dice Score = 0.9320
# 2025-09-08 11:43:33,610 - INFO - spleen_18_slice_35_segmentation.png: Dice Score = 0.9419
# 2025-09-08 11:43:33,633 - INFO - spleen_18_slice_43_segmentation.png: Dice Score = 0.9365
# 2025-09-08 11:43:33,668 - INFO - spleen_18_slice_44_segmentation.png: Dice Score = 0.9252
# 2025-09-08 11:43:33,704 - INFO - spleen_18_slice_40_segmentation.png: Dice Score = 0.9318
# 2025-09-08 11:43:33,716 - INFO - spleen_18_slice_41_segmentation.png: Dice Score = 0.9385
# 2025-09-08 11:43:33,718 - INFO - spleen_18_slice_32_segmentation.png: Dice Score = 0.9413
# 2025-09-08 11:43:33,818 - INFO - spleen_18_slice_42_segmentation.png: Dice Score = 0.9360
# 2025-09-08 11:43:33,866 - INFO - spleen_18_slice_49_segmentation.png: Dice Score = 0.9376
# 2025-09-08 11:43:33,881 - INFO - spleen_18_slice_45_segmentation.png: Dice Score = 0.9252
# 2025-09-08 11:43:33,886 - INFO - spleen_18_slice_46_segmentation.png: Dice Score = 0.9362
# 2025-09-08 11:43:33,897 - INFO - spleen_18_slice_50_segmentation.png: Dice Score = 0.9295
# 2025-09-08 11:43:33,901 - INFO - spleen_18_slice_39_segmentation.png: Dice Score = 0.9287
# 2025-09-08 11:43:33,945 - INFO - spleen_18_slice_47_segmentation.png: Dice Score = 0.9393
# 2025-09-08 11:43:33,963 - INFO - spleen_18_slice_51_segmentation.png: Dice Score = 0.9317
# 2025-09-08 11:43:33,964 - INFO - spleen_18_slice_48_segmentation.png: Dice Score = 0.9409
# 2025-09-08 11:43:34,058 - INFO - spleen_18_slice_54_segmentation.png: Dice Score = 0.9213
# 2025-09-08 11:43:34,080 - INFO - spleen_18_slice_59_segmentation.png: Dice Score = 0.8532
# 2025-09-08 11:43:34,083 - INFO - spleen_18_slice_58_segmentation.png: Dice Score = 0.8403
# 2025-09-08 11:43:34,098 - INFO - spleen_18_slice_56_segmentation.png: Dice Score = 0.8992
# 2025-09-08 11:43:34,100 - INFO - spleen_18_slice_53_segmentation.png: Dice Score = 0.9319
# 2025-09-08 11:43:34,159 - INFO - spleen_18_slice_52_segmentation.png: Dice Score = 0.9328
# 2025-09-08 11:43:34,164 - INFO - spleen_18_slice_55_segmentation.png: Dice Score = 0.9176
# 2025-09-08 11:43:34,262 - INFO - spleen_18_slice_61_segmentation.png: Dice Score = 0.8084
# 2025-09-08 11:43:34,273 - INFO - spleen_18_slice_57_segmentation.png: Dice Score = 0.8854
# 2025-09-08 11:43:34,333 - INFO - spleen_26_slice_03_segmentation.png: Dice Score = 0.9546
# 2025-09-08 11:43:34,365 - INFO - spleen_26_slice_02_segmentation.png: Dice Score = 0.9600
# 2025-09-08 11:43:34,386 - INFO - spleen_26_slice_04_segmentation.png: Dice Score = 0.9645
# 2025-09-08 11:43:34,465 - INFO - spleen_18_slice_60_segmentation.png: Dice Score = 0.8630
# 2025-09-08 11:43:34,485 - INFO - spleen_26_slice_06_segmentation.png: Dice Score = 0.9602
# 2025-09-08 11:43:34,513 - INFO - spleen_26_slice_10_segmentation.png: Dice Score = 0.9471
# 2025-09-08 11:43:34,527 - INFO - spleen_26_slice_07_segmentation.png: Dice Score = 0.9666
# 2025-09-08 11:43:34,552 - INFO - spleen_26_slice_05_segmentation.png: Dice Score = 0.9645
# 2025-09-08 11:43:34,563 - INFO - spleen_26_slice_08_segmentation.png: Dice Score = 0.9466
# 2025-09-08 11:43:34,581 - INFO - spleen_26_slice_01_segmentation.png: Dice Score = 0.9581
# 2025-09-08 11:43:34,675 - INFO - spleen_26_slice_15_segmentation.png: Dice Score = 0.8161
# 2025-09-08 11:43:34,712 - INFO - spleen_25_slice_02_segmentation.png: Dice Score = 0.8852
# 2025-09-08 11:43:34,730 - INFO - spleen_26_slice_13_segmentation.png: Dice Score = 0.9171
# 2025-09-08 11:43:34,733 - INFO - spleen_26_slice_11_segmentation.png: Dice Score = 0.9315
# 2025-09-08 11:43:34,788 - INFO - spleen_26_slice_14_segmentation.png: Dice Score = 0.8921
# 2025-09-08 11:43:34,815 - INFO - spleen_26_slice_09_segmentation.png: Dice Score = 0.9395
# 2025-09-08 11:43:34,824 - INFO - spleen_25_slice_01_segmentation.png: Dice Score = 0.8572
# 2025-09-08 11:43:34,850 - INFO - spleen_26_slice_12_segmentation.png: Dice Score = 0.9350
# 2025-09-08 11:43:34,960 - INFO - spleen_25_slice_03_segmentation.png: Dice Score = 0.8238
# 2025-09-08 11:43:34,961 - INFO - spleen_25_slice_07_segmentation.png: Dice Score = 0.9418
# 2025-09-08 11:43:34,964 - INFO - spleen_25_slice_06_segmentation.png: Dice Score = 0.9524
# 2025-09-08 11:43:34,989 - INFO - spleen_25_slice_08_segmentation.png: Dice Score = 0.9448
# 2025-09-08 11:43:35,002 - INFO - spleen_25_slice_09_segmentation.png: Dice Score = 0.9275
# 2025-09-08 11:43:35,047 - INFO - spleen_25_slice_05_segmentation.png: Dice Score = 0.9407
# 2025-09-08 11:43:35,052 - INFO - spleen_25_slice_04_segmentation.png: Dice Score = 0.9061
# 2025-09-08 11:43:35,062 - INFO - spleen_25_slice_10_segmentation.png: Dice Score = 0.9251
# 2025-09-08 11:43:35,156 - INFO - spleen_25_slice_11_segmentation.png: Dice Score = 0.9592
# 2025-09-08 11:43:35,169 - INFO - spleen_25_slice_12_segmentation.png: Dice Score = 0.9556
# 2025-09-08 11:43:35,175 - INFO - spleen_25_slice_13_segmentation.png: Dice Score = 0.9627
# 2025-09-08 11:43:35,197 - INFO - spleen_25_slice_14_segmentation.png: Dice Score = 0.9560
# 2025-09-08 11:43:35,210 - INFO - spleen_25_slice_18_segmentation.png: Dice Score = 0.9293
# 2025-09-08 11:43:35,212 - INFO - spleen_25_slice_17_segmentation.png: Dice Score = 0.9457
# 2025-09-08 11:43:35,216 - INFO - spleen_25_slice_16_segmentation.png: Dice Score = 0.9420
# 2025-09-08 11:43:35,291 - INFO - spleen_25_slice_19_segmentation.png: Dice Score = 0.9150
# 2025-09-08 11:43:35,369 - INFO - spleen_25_slice_15_segmentation.png: Dice Score = 0.9512
# 2025-09-08 11:43:35,372 - INFO - spleen_25_slice_21_segmentation.png: Dice Score = 0.8996
# 2025-09-08 11:43:35,408 - INFO - spleen_21_slice_03_segmentation.png: Dice Score = 0.8675
# 2025-09-08 11:43:35,378 - INFO - spleen_25_slice_22_segmentation.png: Dice Score = 0.8378
# 2025-09-08 11:43:35,402 - INFO - spleen_21_slice_04_segmentation.png: Dice Score = 0.8929
# 2025-09-08 11:43:35,403 - INFO - spleen_21_slice_01_segmentation.png: Dice Score = 0.8063
# 2025-09-08 11:43:35,403 - INFO - spleen_21_slice_02_segmentation.png: Dice Score = 0.8512
# 2025-09-08 11:43:35,374 - INFO - spleen_25_slice_20_segmentation.png: Dice Score = 0.8474
# 2025-09-08 11:43:35,511 - INFO - spleen_21_slice_05_segmentation.png: Dice Score = 0.9150
# 2025-09-08 11:43:35,516 - INFO - spleen_21_slice_06_segmentation.png: Dice Score = 0.9255
# 2025-09-08 11:43:35,554 - INFO - spleen_21_slice_09_segmentation.png: Dice Score = 0.9349
# 2025-09-08 11:43:35,564 - INFO - spleen_21_slice_07_segmentation.png: Dice Score = 0.9338
# 2025-09-08 11:43:35,565 - INFO - spleen_21_slice_08_segmentation.png: Dice Score = 0.9317
# 2025-09-08 11:43:35,589 - INFO - spleen_21_slice_11_segmentation.png: Dice Score = 0.9147
# 2025-09-08 11:43:35,610 - INFO - spleen_21_slice_10_segmentation.png: Dice Score = 0.9222
# 2025-09-08 11:43:35,616 - INFO - spleen_21_slice_12_segmentation.png: Dice Score = 0.9247
# 2025-09-08 11:43:35,619 - INFO - spleen_21_slice_13_segmentation.png: Dice Score = 0.9199
# 2025-09-08 11:43:35,651 - INFO - spleen_21_slice_14_segmentation.png: Dice Score = 0.9363
# 2025-09-08 11:43:35,669 - INFO - spleen_21_slice_17_segmentation.png: Dice Score = 0.9345
# 2025-09-08 11:43:35,678 - INFO - spleen_21_slice_21_segmentation.png: Dice Score = 0.9552
# 2025-09-08 11:43:35,679 - INFO - spleen_21_slice_20_segmentation.png: Dice Score = 0.9519
# 2025-09-08 11:43:35,680 - INFO - spleen_21_slice_16_segmentation.png: Dice Score = 0.9362
# 2025-09-08 11:43:35,697 - INFO - spleen_21_slice_19_segmentation.png: Dice Score = 0.9409
# 2025-09-08 11:43:35,797 - INFO - spleen_21_slice_23_segmentation.png: Dice Score = 0.9483
# 2025-09-08 11:43:35,803 - INFO - spleen_21_slice_24_segmentation.png: Dice Score = 0.9529
# 2025-09-08 11:43:35,838 - INFO - spleen_21_slice_22_segmentation.png: Dice Score = 0.9440
# 2025-09-08 11:43:35,888 - INFO - spleen_21_slice_26_segmentation.png: Dice Score = 0.9493
# 2025-09-08 11:43:35,872 - INFO - spleen_21_slice_27_segmentation.png: Dice Score = 0.9427
# 2025-09-08 11:43:35,872 - INFO - spleen_21_slice_25_segmentation.png: Dice Score = 0.9490
# 2025-09-08 11:43:35,888 - INFO - spleen_21_slice_28_segmentation.png: Dice Score = 0.9172
# 2025-09-08 11:43:35,855 - INFO - spleen_21_slice_15_segmentation.png: Dice Score = 0.9413
# 2025-09-08 11:43:35,971 - INFO - spleen_21_slice_30_segmentation.png: Dice Score = 0.9364
# 2025-09-08 11:43:35,971 - INFO - spleen_21_slice_29_segmentation.png: Dice Score = 0.9317
# 2025-09-08 11:43:36,055 - INFO - spleen_21_slice_31_segmentation.png: Dice Score = 0.9314
# 2025-09-08 11:43:36,091 - INFO - spleen_21_slice_18_segmentation.png: Dice Score = 0.9330
# 2025-09-08 11:43:36,105 - INFO - spleen_21_slice_32_segmentation.png: Dice Score = 0.9374
# 2025-09-08 11:43:36,121 - INFO - spleen_21_slice_33_segmentation.png: Dice Score = 0.9340
# 2025-09-08 11:43:36,138 - INFO - spleen_21_slice_34_segmentation.png: Dice Score = 0.9192
# 2025-09-08 11:43:36,138 - INFO - spleen_21_slice_35_segmentation.png: Dice Score = 0.8760
# 2025-09-08 11:43:36,171 - INFO - spleen_20_slice_02_segmentation.png: Dice Score = 0.8883
# 2025-09-08 11:43:36,171 - INFO - spleen_20_slice_01_segmentation.png: Dice Score = 0.8855
# 2025-09-08 11:43:36,321 - INFO - spleen_20_slice_10_segmentation.png: Dice Score = 0.9266
# 2025-09-08 11:43:36,371 - INFO - spleen_20_slice_05_segmentation.png: Dice Score = 0.9248
# 2025-09-08 11:43:36,338 - INFO - spleen_20_slice_06_segmentation.png: Dice Score = 0.9237
# 2025-09-08 11:43:36,353 - INFO - spleen_20_slice_04_segmentation.png: Dice Score = 0.9105
# 2025-09-08 11:43:36,354 - INFO - spleen_20_slice_07_segmentation.png: Dice Score = 0.9265
# 2025-09-08 11:43:36,371 - INFO - spleen_20_slice_09_segmentation.png: Dice Score = 0.9242
# 2025-09-08 11:43:36,338 - INFO - spleen_20_slice_03_segmentation.png: Dice Score = 0.9019
# 2025-09-08 11:43:36,421 - INFO - spleen_20_slice_08_segmentation.png: Dice Score = 0.9271
# 2025-09-08 11:43:36,555 - INFO - spleen_20_slice_14_segmentation.png: Dice Score = 0.9352
# 2025-09-08 11:43:36,571 - INFO - spleen_20_slice_15_segmentation.png: Dice Score = 0.9323
# 2025-09-08 11:43:36,571 - INFO - spleen_20_slice_13_segmentation.png: Dice Score = 0.9336
# 2025-09-08 11:43:36,588 - INFO - spleen_20_slice_17_segmentation.png: Dice Score = 0.9334
# 2025-09-08 11:43:36,620 - INFO - spleen_20_slice_11_segmentation.png: Dice Score = 0.9298
# 2025-09-08 11:43:36,638 - INFO - spleen_20_slice_16_segmentation.png: Dice Score = 0.9313
# 2025-09-08 11:43:36,671 - INFO - spleen_20_slice_19_segmentation.png: Dice Score = 0.9447
# 2025-09-08 11:43:36,704 - INFO - spleen_20_slice_12_segmentation.png: Dice Score = 0.9385
# 2025-09-08 11:43:36,721 - INFO - spleen_20_slice_22_segmentation.png: Dice Score = 0.9464
# 2025-09-08 11:43:36,772 - INFO - spleen_20_slice_20_segmentation.png: Dice Score = 0.9432
# 2025-09-08 11:43:36,838 - INFO - spleen_20_slice_18_segmentation.png: Dice Score = 0.9411
# 2025-09-08 11:43:36,854 - INFO - spleen_20_slice_24_segmentation.png: Dice Score = 0.9437
# 2025-09-08 11:43:36,904 - INFO - spleen_20_slice_21_segmentation.png: Dice Score = 0.9424
# 2025-09-08 11:43:36,921 - INFO - spleen_20_slice_26_segmentation.png: Dice Score = 0.9226
# 2025-09-08 11:43:36,937 - INFO - spleen_20_slice_27_segmentation.png: Dice Score = 0.8952
# 2025-09-08 11:43:36,937 - INFO - spleen_20_slice_23_segmentation.png: Dice Score = 0.9440
# 2025-09-08 11:43:36,937 - INFO - spleen_20_slice_28_segmentation.png: Dice Score = 0.9140
# 2025-09-08 11:43:37,004 - INFO - spleen_20_slice_29_segmentation.png: Dice Score = 0.9207
# 2025-09-08 11:43:37,060 - INFO - spleen_20_slice_34_segmentation.png: Dice Score = 0.9504
# 2025-09-08 11:43:37,088 - INFO - spleen_20_slice_33_segmentation.png: Dice Score = 0.9486
# 2025-09-08 11:43:37,106 - INFO - spleen_20_slice_25_segmentation.png: Dice Score = 0.9458
# 2025-09-08 11:43:37,109 - INFO - spleen_20_slice_30_segmentation.png: Dice Score = 0.9219
# 2025-09-08 11:43:37,169 - INFO - spleen_20_slice_31_segmentation.png: Dice Score = 0.9286
# 2025-09-08 11:43:37,170 - INFO - spleen_20_slice_36_segmentation.png: Dice Score = 0.9479
# 2025-09-08 11:43:37,194 - INFO - spleen_20_slice_35_segmentation.png: Dice Score = 0.9497
# 2025-09-08 11:43:37,211 - INFO - spleen_20_slice_32_segmentation.png: Dice Score = 0.9395
# 2025-09-08 11:43:37,222 - INFO - spleen_20_slice_39_segmentation.png: Dice Score = 0.9507
# 2025-09-08 11:43:37,254 - INFO - spleen_20_slice_37_segmentation.png: Dice Score = 0.9534
# 2025-09-08 11:43:37,287 - INFO - spleen_20_slice_40_segmentation.png: Dice Score = 0.9520
# 2025-09-08 11:43:37,320 - INFO - spleen_20_slice_43_segmentation.png: Dice Score = 0.9489
# 2025-09-08 11:43:37,378 - INFO - spleen_20_slice_44_segmentation.png: Dice Score = 0.9480
# 2025-09-08 11:43:37,420 - INFO - spleen_20_slice_45_segmentation.png: Dice Score = 0.9489
# 2025-09-08 11:43:37,420 - INFO - spleen_20_slice_38_segmentation.png: Dice Score = 0.9528
# 2025-09-08 11:43:37,437 - INFO - spleen_20_slice_41_segmentation.png: Dice Score = 0.9554
# 2025-09-08 11:43:37,454 - INFO - spleen_20_slice_47_segmentation.png: Dice Score = 0.9497
# 2025-09-08 11:43:37,454 - INFO - spleen_20_slice_48_segmentation.png: Dice Score = 0.9464
# 2025-09-08 11:43:37,537 - INFO - spleen_20_slice_42_segmentation.png: Dice Score = 0.9572
# 2025-09-08 11:43:37,554 - INFO - spleen_20_slice_49_segmentation.png: Dice Score = 0.9495
# 2025-09-08 11:43:37,569 - INFO - spleen_20_slice_51_segmentation.png: Dice Score = 0.9480
# 2025-09-08 11:43:37,621 - INFO - spleen_20_slice_46_segmentation.png: Dice Score = 0.9476
# ...
# 2025-09-08 11:43:43,841 - INFO - spleen_40_slice_02_segmentation.png: Dice Score = 0.9217
# 2025-09-08 11:43:43,868 - INFO - spleen_38_slice_03_segmentation.png: Dice Score = 0.9426
# 2025-09-08 11:43:43,891 - INFO - spleen_40_slice_01_segmentation.png: Dice Score = 0.8129
# 2025-09-08 11:43:43,921 - INFO - spleen_40_slice_06_segmentation.png: Dice Score = 0.8604
# 2025-09-08 11:43:43,940 - INFO - spleen_40_slice_05_segmentation.png: Dice Score = 0.9446
# 2025-09-08 11:43:43,958 - INFO - spleen_40_slice_03_segmentation.png: Dice Score = 0.9338
# 2025-09-08 11:43:43,991 - INFO - spleen_40_slice_10_segmentation.png: Dice Score = 0.9389
# 2025-09-08 11:43:44,002 - INFO - spleen_40_slice_07_segmentation.png: Dice Score = 0.9175
# 2025-09-08 11:43:44,024 - INFO - spleen_40_slice_08_segmentation.png: Dice Score = 0.9238
# 2025-09-08 11:43:44,096 - INFO - spleen_40_slice_13_segmentation.png: Dice Score = 0.8978
# 2025-09-08 11:43:44,127 - INFO - spleen_40_slice_14_segmentation.png: Dice Score = 0.8477
# 2025-09-08 11:43:44,138 - INFO - spleen_40_slice_11_segmentation.png: Dice Score = 0.9311
# 2025-09-08 11:43:44,140 - INFO - spleen_40_slice_04_segmentation.png: Dice Score = 0.9458
# 2025-09-08 11:43:44,151 - INFO - spleen_40_slice_15_segmentation.png: Dice Score = 0.8931
# 2025-09-08 11:43:44,151 - INFO - spleen_40_slice_09_segmentation.png: Dice Score = 0.9557
# 2025-09-08 11:43:44,173 - INFO - spleen_40_slice_12_segmentation.png: Dice Score = 0.9253
# 2025-09-08 11:43:44,290 - INFO - spleen_41_slice_03_segmentation.png: Dice Score = 0.9041
# 2025-09-08 11:43:44,294 - INFO - spleen_41_slice_04_segmentation.png: Dice Score = 0.9089
# 2025-09-08 11:43:44,304 - INFO - spleen_41_slice_06_segmentation.png: Dice Score = 0.9371
# 2025-09-08 11:43:44,362 - INFO - spleen_41_slice_07_segmentation.png: Dice Score = 0.9282
# 2025-09-08 11:43:44,422 - INFO - spleen_41_slice_01_segmentation.png: Dice Score = 0.7080
# 2025-09-08 11:43:44,454 - INFO - spleen_41_slice_08_segmentation.png: Dice Score = 0.9435
# 2025-09-08 11:43:44,468 - INFO - spleen_41_slice_10_segmentation.png: Dice Score = 0.9445
# 2025-09-08 11:43:44,471 - INFO - spleen_41_slice_09_segmentation.png: Dice Score = 0.9214
# 2025-09-08 11:43:44,472 - INFO - spleen_41_slice_02_segmentation.png: Dice Score = 0.8891
# 2025-09-08 11:43:44,549 - INFO - spleen_41_slice_05_segmentation.png: Dice Score = 0.9313
# 2025-09-08 11:43:44,551 - INFO - spleen_41_slice_13_segmentation.png: Dice Score = 0.8718
# 2025-09-08 11:43:44,563 - INFO - spleen_41_slice_11_segmentation.png: Dice Score = 0.9199
# 2025-09-08 11:43:44,591 - INFO - spleen_40_slice_16_segmentation.png: Dice Score = 0.8407
# 2025-09-08 11:43:44,609 - INFO - spleen_41_slice_16_segmentation.png: Dice Score = 0.8543
# 2025-09-08 11:43:44,619 - INFO - spleen_41_slice_15_segmentation.png: Dice Score = 0.8657
# 2025-09-08 11:43:44,665 - INFO - spleen_44_slice_01_segmentation.png: Dice Score = 0.4925
# 2025-09-08 11:43:44,680 - INFO - spleen_41_slice_17_segmentation.png: Dice Score = 0.8245
# 2025-09-08 11:43:44,697 - INFO - spleen_41_slice_14_segmentation.png: Dice Score = 0.8757
# 2025-09-08 11:43:44,725 - INFO - spleen_44_slice_02_segmentation.png: Dice Score = 0.0227
# 2025-09-08 11:43:44,733 - INFO - spleen_44_slice_03_segmentation.png: Dice Score = 0.0337
# 2025-09-08 11:43:44,737 - INFO - spleen_44_slice_04_segmentation.png: Dice Score = 0.7777
# 2025-09-08 11:43:44,777 - INFO - spleen_44_slice_06_segmentation.png: Dice Score = 0.8922
# 2025-09-08 11:43:44,817 - INFO - spleen_41_slice_12_segmentation.png: Dice Score = 0.9191
# 2025-09-08 11:43:44,818 - INFO - spleen_44_slice_08_segmentation.png: Dice Score = 0.8924
# 2025-09-08 11:43:44,851 - INFO - spleen_45_slice_01_segmentation.png: Dice Score = 0.7239
# 2025-09-08 11:43:44,865 - INFO - spleen_44_slice_10_segmentation.png: Dice Score = 0.7261
# 2025-09-08 11:43:44,869 - INFO - spleen_44_slice_05_segmentation.png: Dice Score = 0.8713
# 2025-09-08 11:43:44,890 - INFO - spleen_44_slice_09_segmentation.png: Dice Score = 0.8684
# 2025-09-08 11:43:44,936 - INFO - spleen_45_slice_02_segmentation.png: Dice Score = 0.8277
# 2025-09-08 11:43:44,963 - INFO - spleen_45_slice_05_segmentation.png: Dice Score = 0.8826
# 2025-09-08 11:43:44,974 - INFO - spleen_45_slice_07_segmentation.png: Dice Score = 0.9290
# 2025-09-08 11:43:44,997 - INFO - spleen_45_slice_06_segmentation.png: Dice Score = 0.9216
# 2025-09-08 11:43:45,003 - INFO - spleen_44_slice_07_segmentation.png: Dice Score = 0.9200
# 2025-09-08 11:43:45,033 - INFO - spleen_45_slice_08_segmentation.png: Dice Score = 0.9104
# 2025-09-08 11:43:45,045 - INFO - spleen_45_slice_04_segmentation.png: Dice Score = 0.7919
# 2025-09-08 11:43:45,062 - INFO - spleen_45_slice_10_segmentation.png: Dice Score = 0.9093
# 2025-09-08 11:43:45,099 - INFO - spleen_45_slice_09_segmentation.png: Dice Score = 0.9294
# 2025-09-08 11:43:45,108 - INFO - spleen_45_slice_11_segmentation.png: Dice Score = 0.9172
# 2025-09-08 11:43:45,124 - INFO - spleen_45_slice_12_segmentation.png: Dice Score = 0.8770
# 2025-09-08 11:43:45,146 - INFO - spleen_45_slice_16_segmentation.png: Dice Score = 0.9299
# 2025-09-08 11:43:45,180 - INFO - spleen_45_slice_13_segmentation.png: Dice Score = 0.9250
# 2025-09-08 11:43:45,198 - INFO - spleen_45_slice_03_segmentation.png: Dice Score = 0.7552
# 2025-09-08 11:43:45,251 - INFO - spleen_45_slice_18_segmentation.png: Dice Score = 0.9088
# 2025-09-08 11:43:45,260 - INFO - spleen_45_slice_21_segmentation.png: Dice Score = 0.7735
# 2025-09-08 11:43:45,270 - INFO - spleen_45_slice_17_segmentation.png: Dice Score = 0.9152
# 2025-09-08 11:43:45,281 - INFO - spleen_45_slice_15_segmentation.png: Dice Score = 0.9366
# 2025-09-08 11:43:45,292 - INFO - spleen_45_slice_19_segmentation.png: Dice Score = 0.8383
# 2025-09-08 11:43:45,299 - INFO - spleen_45_slice_20_segmentation.png: Dice Score = 0.7704
# 2025-09-08 11:43:45,401 - INFO - spleen_56_slice_03_segmentation.png: Dice Score = 0.9002
# 2025-09-08 11:43:45,414 - INFO - spleen_45_slice_14_segmentation.png: Dice Score = 0.9321
# 2025-09-08 11:43:45,443 - INFO - spleen_56_slice_02_segmentation.png: Dice Score = 0.5967
# 2025-09-08 11:43:45,479 - INFO - spleen_56_slice_01_segmentation.png: Dice Score = 0.8606
# 2025-09-08 11:43:45,481 - INFO - spleen_56_slice_06_segmentation.png: Dice Score = 0.9353
# 2025-09-08 11:43:45,499 - INFO - spleen_56_slice_05_segmentation.png: Dice Score = 0.9260
# 2025-09-08 11:43:45,509 - INFO - spleen_56_slice_04_segmentation.png: Dice Score = 0.9242
# 2025-09-08 11:43:45,549 - INFO - spleen_56_slice_07_segmentation.png: Dice Score = 0.9503
# 2025-09-08 11:43:45,565 - INFO - spleen_56_slice_08_segmentation.png: Dice Score = 0.9326
# 2025-09-08 11:43:45,647 - INFO - spleen_46_slice_02_segmentation.png: Dice Score = 0.9318
# 2025-09-08 11:43:45,656 - INFO - spleen_46_slice_01_segmentation.png: Dice Score = 0.8457
# 2025-09-08 11:43:45,655 - INFO - spleen_46_slice_04_segmentation.png: Dice Score = 0.9313
# 2025-09-08 11:43:45,664 - INFO - spleen_46_slice_07_segmentation.png: Dice Score = 0.9364
# 2025-09-08 11:43:45,716 - INFO - spleen_46_slice_06_segmentation.png: Dice Score = 0.9483
# 2025-09-08 11:43:45,734 - INFO - spleen_46_slice_05_segmentation.png: Dice Score = 0.9481
# 2025-09-08 11:43:45,768 - INFO - spleen_56_slice_09_segmentation.png: Dice Score = 0.8736
# 2025-09-08 11:43:45,789 - INFO - spleen_46_slice_10_segmentation.png: Dice Score = 0.9575
# 2025-09-08 11:43:45,800 - INFO - spleen_46_slice_09_segmentation.png: Dice Score = 0.9560
# 2025-09-08 11:43:45,828 - INFO - spleen_46_slice_08_segmentation.png: Dice Score = 0.9416
# 2025-09-08 11:43:45,849 - INFO - spleen_46_slice_12_segmentation.png: Dice Score = 0.9592
# 2025-09-08 11:43:45,852 - INFO - spleen_46_slice_03_segmentation.png: Dice Score = 0.9234
# 2025-09-08 11:43:45,913 - INFO - spleen_46_slice_15_segmentation.png: Dice Score = 0.9312
# 2025-09-08 11:43:45,932 - INFO - spleen_46_slice_13_segmentation.png: Dice Score = 0.9527
# 2025-09-08 11:43:45,936 - INFO - spleen_46_slice_11_segmentation.png: Dice Score = 0.9652
# 2025-09-08 11:43:45,999 - INFO - spleen_49_slice_02_segmentation.png: Dice Score = 0.9226
# 2025-09-08 11:43:46,004 - INFO - spleen_46_slice_16_segmentation.png: Dice Score = 0.9282
# 2025-09-08 11:43:46,053 - INFO - spleen_49_slice_04_segmentation.png: Dice Score = 0.8807
# 2025-09-08 11:43:46,060 - INFO - spleen_49_slice_01_segmentation.png: Dice Score = 0.8806
# 2025-09-08 11:43:46,066 - INFO - spleen_49_slice_03_segmentation.png: Dice Score = 0.9288
# 2025-09-08 11:43:46,098 - INFO - spleen_46_slice_17_segmentation.png: Dice Score = 0.8831
# 2025-09-08 11:43:46,127 - INFO - spleen_46_slice_14_segmentation.png: Dice Score = 0.9312
# 2025-09-08 11:43:46,128 - INFO - spleen_49_slice_06_segmentation.png: Dice Score = 0.9350
# 2025-09-08 11:43:46,149 - INFO - spleen_49_slice_09_segmentation.png: Dice Score = 0.9346
# 2025-09-08 11:43:46,201 - INFO - spleen_49_slice_08_segmentation.png: Dice Score = 0.9476
# 2025-09-08 11:43:46,205 - INFO - spleen_49_slice_10_segmentation.png: Dice Score = 0.9500
# 2025-09-08 11:43:46,231 - INFO - spleen_49_slice_07_segmentation.png: Dice Score = 0.9440
# 2025-09-08 11:43:46,257 - INFO - spleen_49_slice_12_segmentation.png: Dice Score = 0.9482
# 2025-09-08 11:43:46,259 - INFO - spleen_49_slice_13_segmentation.png: Dice Score = 0.9459
# 2025-09-08 11:43:46,306 - INFO - spleen_49_slice_14_segmentation.png: Dice Score = 0.9518
# 2025-09-08 11:43:46,333 - INFO - spleen_49_slice_05_segmentation.png: Dice Score = 0.8532
# 2025-09-08 11:43:46,348 - INFO - spleen_49_slice_16_segmentation.png: Dice Score = 0.9601
# 2025-09-08 11:43:46,352 - INFO - spleen_49_slice_17_segmentation.png: Dice Score = 0.9607
# 2025-09-08 11:43:46,362 - INFO - spleen_49_slice_11_segmentation.png: Dice Score = 0.9563
# 2025-09-08 11:43:46,368 - INFO - spleen_49_slice_15_segmentation.png: Dice Score = 0.9514
# 2025-09-08 11:43:46,380 - INFO - spleen_49_slice_18_segmentation.png: Dice Score = 0.9380
# 2025-09-08 11:43:46,463 - INFO - spleen_49_slice_19_segmentation.png: Dice Score = 0.9596
# 2025-09-08 11:43:46,497 - INFO - spleen_49_slice_24_segmentation.png: Dice Score = 0.8993
# 2025-09-08 11:43:46,499 - INFO - spleen_49_slice_23_segmentation.png: Dice Score = 0.9275
# 2025-09-08 11:43:46,509 - INFO - spleen_49_slice_22_segmentation.png: Dice Score = 0.9572
# 2025-09-08 11:43:46,550 - INFO - spleen_47_slice_01_segmentation.png: Dice Score = 0.6412
# 2025-09-08 11:43:46,554 - INFO - spleen_49_slice_21_segmentation.png: Dice Score = 0.9495
# 2025-09-08 11:43:46,556 - INFO - spleen_49_slice_25_segmentation.png: Dice Score = 0.8013
# 2025-09-08 11:43:46,687 - INFO - spleen_49_slice_20_segmentation.png: Dice Score = 0.9439
# 2025-09-08 11:43:46,695 - INFO - spleen_47_slice_07_segmentation.png: Dice Score = 0.8699
# 2025-09-08 11:43:46,717 - INFO - spleen_47_slice_02_segmentation.png: Dice Score = 0.9192
# 2025-09-08 11:43:46,737 - INFO - spleen_47_slice_03_segmentation.png: Dice Score = 0.9323
# 2025-09-08 11:43:46,722 - INFO - spleen_47_slice_05_segmentation.png: Dice Score = 0.9561
# 2025-09-08 11:43:46,911 - INFO - spleen_47_slice_08_segmentation.png: Dice Score = 0.8800
# 2025-09-08 11:43:46,915 - INFO - spleen_47_slice_10_segmentation.png: Dice Score = 0.8795
# 2025-09-08 11:43:46,955 - INFO - spleen_47_slice_04_segmentation.png: Dice Score = 0.9364
# 2025-09-08 11:43:46,958 - INFO - spleen_47_slice_11_segmentation.png: Dice Score = 0.9282
# 2025-09-08 11:43:46,960 - INFO - spleen_47_slice_06_segmentation.png: Dice Score = 0.9386
# 2025-09-08 11:43:46,989 - INFO - spleen_47_slice_13_segmentation.png: Dice Score = 0.9571
# 2025-09-08 11:43:47,002 - INFO - spleen_47_slice_12_segmentation.png: Dice Score = 0.9356
# 2025-09-08 11:43:47,032 - INFO - spleen_47_slice_09_segmentation.png: Dice Score = 0.8864
# 2025-09-08 11:43:47,046 - INFO - spleen_47_slice_16_segmentation.png: Dice Score = 0.9399
# 2025-09-08 11:43:47,092 - INFO - spleen_47_slice_17_segmentation.png: Dice Score = 0.9527
# 2025-09-08 11:43:47,139 - INFO - spleen_47_slice_18_segmentation.png: Dice Score = 0.9327
# 2025-09-08 11:43:47,161 - INFO - spleen_47_slice_20_segmentation.png: Dice Score = 0.8920
# 2025-09-08 11:43:47,203 - INFO - spleen_47_slice_22_segmentation.png: Dice Score = 0.8730
# 2025-09-08 11:43:47,218 - INFO - spleen_47_slice_14_segmentation.png: Dice Score = 0.9589
# 2025-09-08 11:43:47,229 - INFO - spleen_59_slice_01_segmentation.png: Dice Score = 0.5567
# 2025-09-08 11:43:47,246 - INFO - spleen_47_slice_15_segmentation.png: Dice Score = 0.9501
# 2025-09-08 11:43:47,270 - INFO - spleen_47_slice_21_segmentation.png: Dice Score = 0.8261
# 2025-09-08 11:43:47,283 - INFO - spleen_59_slice_02_segmentation.png: Dice Score = 0.8306
# 2025-09-08 11:43:47,284 - INFO - spleen_47_slice_19_segmentation.png: Dice Score = 0.9178
# 2025-09-08 11:43:47,297 - INFO - spleen_59_slice_03_segmentation.png: Dice Score = 0.9021
# 2025-09-08 11:43:47,351 - INFO - spleen_59_slice_05_segmentation.png: Dice Score = 0.9432
# 2025-09-08 11:43:47,367 - INFO - spleen_59_slice_08_segmentation.png: Dice Score = 0.9416
# 2025-09-08 11:43:47,399 - INFO - spleen_59_slice_04_segmentation.png: Dice Score = 0.9340
# 2025-09-08 11:43:47,437 - INFO - spleen_59_slice_06_segmentation.png: Dice Score = 0.9492
# 2025-09-08 11:43:47,445 - INFO - spleen_59_slice_10_segmentation.png: Dice Score = 0.9412
# 2025-09-08 11:43:47,480 - INFO - spleen_59_slice_13_segmentation.png: Dice Score = 0.9348
# 2025-09-08 11:43:47,499 - INFO - spleen_59_slice_11_segmentation.png: Dice Score = 0.9513
# 2025-09-08 11:43:47,507 - INFO - spleen_59_slice_12_segmentation.png: Dice Score = 0.9172
# 2025-09-08 11:43:47,511 - INFO - spleen_59_slice_09_segmentation.png: Dice Score = 0.9530
# 2025-09-08 11:43:47,522 - INFO - spleen_59_slice_07_segmentation.png: Dice Score = 0.9539
# 2025-09-08 11:43:47,553 - INFO - spleen_59_slice_14_segmentation.png: Dice Score = 0.9437
# 2025-09-08 11:43:47,573 - INFO - spleen_59_slice_15_segmentation.png: Dice Score = 0.9229
# 2025-09-08 11:43:47,577 - INFO - spleen_59_slice_16_segmentation.png: Dice Score = 0.9235
# 2025-09-08 11:43:47,622 - INFO - spleen_59_slice_18_segmentation.png: Dice Score = 0.8943
# 2025-09-08 11:43:47,628 - INFO - spleen_59_slice_20_segmentation.png: Dice Score = 0.8662
# 2025-09-08 11:43:47,633 - INFO - spleen_59_slice_19_segmentation.png: Dice Score = 0.8579
# 2025-09-08 11:43:47,660 - INFO - spleen_59_slice_23_segmentation.png: Dice Score = 0.7924
# 2025-09-08 11:43:47,720 - INFO - spleen_52_slice_04_segmentation.png: Dice Score = 0.9397
# 2025-09-08 11:43:47,734 - INFO - spleen_59_slice_21_segmentation.png: Dice Score = 0.8342
# 2025-09-08 11:43:47,748 - INFO - spleen_52_slice_03_segmentation.png: Dice Score = 0.9306
# 2025-09-08 11:43:47,768 - INFO - spleen_52_slice_05_segmentation.png: Dice Score = 0.9477
# 2025-09-08 11:43:47,837 - INFO - spleen_59_slice_22_segmentation.png: Dice Score = 0.7766
# 2025-09-08 11:43:47,842 - INFO - spleen_52_slice_01_segmentation.png: Dice Score = 0.7320
# 2025-09-08 11:43:47,858 - INFO - spleen_59_slice_17_segmentation.png: Dice Score = 0.9177
# 2025-09-08 11:43:47,855 - INFO - spleen_52_slice_06_segmentation.png: Dice Score = 0.9527
# 2025-09-08 11:43:47,851 - INFO - spleen_52_slice_07_segmentation.png: Dice Score = 0.9458
# 2025-09-08 11:43:47,911 - INFO - spleen_52_slice_02_segmentation.png: Dice Score = 0.8973
# 2025-09-08 11:43:47,956 - INFO - spleen_52_slice_10_segmentation.png: Dice Score = 0.9540
# 2025-09-08 11:43:47,963 - INFO - spleen_52_slice_11_segmentation.png: Dice Score = 0.9583
# 2025-09-08 11:43:47,973 - INFO - spleen_52_slice_12_segmentation.png: Dice Score = 0.9623
# 2025-09-08 11:43:48,007 - INFO - spleen_52_slice_08_segmentation.png: Dice Score = 0.9468
# 2025-09-08 11:43:48,021 - INFO - spleen_52_slice_14_segmentation.png: Dice Score = 0.9532
# 2025-09-08 11:43:48,023 - INFO - spleen_52_slice_09_segmentation.png: Dice Score = 0.9455
# 2025-09-08 11:43:48,120 - INFO - spleen_52_slice_16_segmentation.png: Dice Score = 0.9578
# 2025-09-08 11:43:48,126 - INFO - spleen_52_slice_13_segmentation.png: Dice Score = 0.9601
# 2025-09-08 11:43:48,147 - INFO - spleen_52_slice_19_segmentation.png: Dice Score = 0.9533

# %%
# Ergebnisse speichern und analysieren
if dice_scores:
    # Ergebnisse in CSV speichern
    with open("dice_scores.csv", "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Maskenname", "Dice Score"])
        writer.writerows(dice_scores)

    # Durchschnitt berechnen
    dice_values = [score for _, score in dice_scores]
    avg_dice = np.mean(dice_values)
    logging.info(f"\nDurchschnittlicher Dice Score: {avg_dice:.4f}")

    # Histogramm erstellen
    plt.figure(figsize=(8, 6))
    plt.hist(dice_values, bins=20, color='blue', alpha=0.7, edgecolor='black')
    plt.title('Distribution of dice scores')
    plt.xlabel('Dice Score')
    plt.ylabel('Frequency')
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Durchschnitt im Histogramm markieren
    plt.axvline(avg_dice, color='red', linestyle='dashed', linewidth=1.5, label=f'Durchschnitt: {avg_dice:.4f}')
    plt.legend()

    # Plot speichern und anzeigen
    plt.savefig('data\Spleen\dice_score_histogram_MedSAM_Spleen.png')
    plt.show()
else:
    logging.info("Keine Dice Scores berechnet!")

# %%
import nibabel as nib

nii = nib.load("data/Spleen/output_images/spleen_63.nii.gz")
spacing = nii.header.get_zooms()[:2]  # (dy, dx) Pixel Spacing in mm
print("Pixel Spacing:", spacing)

# %%
import os
import numpy as np
import cv2
import logging
import csv
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from scipy import ndimage as ndi

# ---------------- Logging ----------------
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# ---------------- Pfade (wie bei dir) ----------------
mask_png_folder = os.path.join("data", "Spleen", "output_masks_updated")
segmentation_results_folder = os.path.join("data", "Spleen", "segmentation_results")

# ---------------- Parameter ----------------
# Pixelabstände in mm (für PNGs meist unbekannt → 1.0 annehmen, sonst hier anpassen)
pixel_spacing = (1.0, 1.0)  # (dy, dx) in mm

# ---------------- Hilfsfunktionen ----------------
def _check_binary_2d(a: np.ndarray) -> np.ndarray:
    """Sicherstellen, dass 2D & binär (0/1)."""
    if a.ndim != 2:
        raise ValueError("Erwarte 2D-Maske (ein Slice).")
    return (a > 0).astype(np.uint8)

def _surface_2d(mask: np.ndarray) -> np.ndarray:
    """2D-Oberflächenpunkte (Randpixel) einer binären Maske."""
    if mask.sum() == 0:
        return mask.astype(bool)
    eroded = ndi.binary_erosion(mask, iterations=1, border_value=0)
    surf = mask.astype(bool) & (~eroded)
    return surf

def _surface_distances_2d(A: np.ndarray, B: np.ndarray, spacing=(1.0, 1.0)) -> np.ndarray:
    """
    Abstände von der Oberfläche von A zur Oberfläche von B (symmetrische Metriken nutzen beide Richtungen).
    Implementierung via EDT des Komplements von B.
    """
    if B.sum() == 0:
        # keine B-Pixel vorhanden -> alle A-Oberflächen haben "unendlichen" Abstand
        d = np.full(A.shape, np.inf, dtype=float)
    else:
        d = ndi.distance_transform_edt(~B.astype(bool), sampling=spacing)
    A_surf = _surface_2d(A)
    return d[A_surf]

def hausdorff_2d(mask1: np.ndarray, mask2: np.ndarray, spacing=(1.0, 1.0), percentile: float | None = None) -> float:
    """
    Hausdorff-Distanz (in mm) zwischen zwei 2D-Binärmasken.
    - percentile=None → klassische HD (Maximum)
    - percentile=95 → HD95 (robuster ggü. Ausreißern)
    """
    a = _check_binary_2d(mask1)
    b = _check_binary_2d(mask2)

    # Sonderfälle
    if a.sum() == 0 and b.sum() == 0:
        return 0.0
    if a.sum() == 0 or b.sum() == 0:
        return float("inf")

    d_ab = _surface_distances_2d(a, b, spacing)
    d_ba = _surface_distances_2d(b, a, spacing)
    all_d = np.concatenate([d_ab, d_ba])

    if all_d.size == 0:
        return 0.0

    if percentile is None:
        return float(np.max(all_d))
    else:
        return float(np.percentile(all_d, percentile))

# ---------------- Einzeldatei-Verarbeitung ----------------
def process_single_file_hd(mask_filename: str):
    """
    Erwartet Masken wie: <basename>_slice_{N}_mask.png
    Sucht dazu:          <basename>.nii.gz_slice_{N-1}_segmentation.png
    """
    base_name = mask_filename.split("_slice_")[0]
    slice_number = mask_filename.split("_slice_")[-1].split("_")[0]
    slice_number_converted = int(slice_number) - 1
    segmentation_filename = f"{base_name}.nii.gz_slice_{slice_number_converted}_segmentation.png"

    mask_png_path = os.path.join(mask_png_folder, mask_filename)
    segmentation_path = os.path.join(segmentation_results_folder, segmentation_filename)

    if not os.path.exists(segmentation_path):
        logging.warning(f"Segmentationsdatei für {mask_filename} nicht gefunden!")
        return None

    try:
        # Masken laden (grau) und binär machen
        mask_png = cv2.imread(mask_png_path, cv2.IMREAD_GRAYSCALE)
        segmentation = cv2.imread(segmentation_path, cv2.IMREAD_GRAYSCALE)

        if mask_png is None or segmentation is None:
            logging.error(f"Fehler beim Laden: {mask_filename}")
            return None

        mask_bin = (mask_png > 0).astype(np.uint8)
        seg_bin  = (segmentation > 0).astype(np.uint8)

        # HD & HD95 berechnen
        hd   = hausdorff_2d(mask_bin, seg_bin, spacing=pixel_spacing, percentile=None)
        hd95 = hausdorff_2d(mask_bin, seg_bin, spacing=pixel_spacing, percentile=95)

        logging.info(f"{mask_filename}: HD = {hd:.3f} mm | HD95 = {hd95:.3f} mm")
        return mask_filename, hd, hd95

    except Exception as e:
        logging.error(f"Fehler beim Verarbeiten von {mask_filename}: {e}")
        return None

# ---------------- Parallelisieren & Sammeln ----------------
results = []
with ThreadPoolExecutor() as executor:
    futures = [
        executor.submit(process_single_file_hd, fn)
        for fn in os.listdir(mask_png_folder)
        if fn.endswith(".png")
    ]
    results = [f.result() for f in futures if f.result() is not None]

# ---------------- Speichern & Visualisieren ----------------
if results:
    # CSV
    csv_path = "MedSAM_Spleen_hausdorff_results.csv"
    with open(csv_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Maskenname", "Hausdorff_mm", "HD95_mm"])
        writer.writerows(results)
    logging.info(f"CSV gespeichert: {csv_path}")

    # Arrays für Plots
    hd_vals   = [r[1] for r in results if np.isfinite(r[1])]
    hd95_vals = [r[2] for r in results if np.isfinite(r[2])]

    # Mittelwerte (ohne inf)
    if hd_vals:
        avg_hd = np.mean(hd_vals)
        logging.info(f"Durchschnittliche HD (ohne ∞): {avg_hd:.3f} mm")
    else:
        avg_hd = None

    if hd95_vals:
        avg_hd95 = np.mean(hd95_vals)
        logging.info(f"Durchschnittliche HD95: {avg_hd95:.3f} mm")
    else:
        avg_hd95 = None

    # Histogramm HD
    if hd_vals:
        plt.figure(figsize=(8, 6))
        plt.hist(hd_vals, bins=20, color='blue', alpha=0.7, edgecolor='black')
        plt.title('Distribution of Hausdorff Distance (mm)')
        plt.xlabel('HD (mm)')
        plt.ylabel('Frequency')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        if avg_hd is not None:
            plt.axvline(avg_hd, color='red', linestyle='dashed', linewidth=1.5, label=f'Avg HD: {avg_hd:.3f} mm')
            plt.legend()
        plot_path_hd = os.path.join("data", "Spleen", "hausdorff_histogram_MedSAM_Spleen.png")
        plt.savefig(plot_path_hd, dpi=150, bbox_inches='tight')
        plt.show()
        logging.info(f"HD-Histogramm gespeichert: {plot_path_hd}")

    # Histogramm HD95
    if hd95_vals:
        plt.figure(figsize=(8, 6))
        plt.hist(hd95_vals, bins=20, color='green', alpha=0.7, edgecolor='black')
        plt.title('Distribution of 95th Percentile Hausdorff Distance (HD95, mm)')
        plt.xlabel('HD95 (mm)')
        plt.ylabel('Frequency')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        if avg_hd95 is not None:
            plt.axvline(avg_hd95, color='red', linestyle='dashed', linewidth=1.5, label=f'Avg HD95: {avg_hd95:.3f} mm')
            plt.legend()
        plot_path_hd95 = os.path.join("data", "Spleen", "hausdorff95_histogram_MedSAM_Spleen.png")
        plt.savefig(plot_path_hd95, dpi=150, bbox_inches='tight')
        plt.show()
        logging.info(f"HD95-Histogramm gespeichert: {plot_path_hd95}")

else:
    logging.info("Keine HD/HD95-Werte berechnet!")

# %% [markdown]
# ### angepassten Code schreiben, der das Pixel Spacing automatisch aus den NIfTI-Dateien ausliest und pro Slice korrekt anwendet?

# %%
import os
import numpy as np
import cv2
import logging
import csv
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from scipy import ndimage as ndi
import nibabel as nib  # <— NEU

# ---------------- Logging ----------------
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# ---------------- Pfade ----------------
mask_png_folder = os.path.join("data", "Spleen", "output_masks_updated")
segmentation_results_folder = os.path.join("data", "Spleen", "segmentation_results")
nii_root = os.path.join("data", "Spleen", "output_images")  # <— Ordner mit deinen .nii/.nii.gz Dateien

# ---------------- Spacing-Cache ----------------
spacing_cache = {}  # map: base_name -> (dy, dx) in mm

def _get_spacing_from_nifti(base_name: str) -> tuple[float, float]:
    """
    Liest (dy, dx) aus dem NIfTI-Header von <nii_root>/<base_name>.nii.gz bzw. .nii.
    Cacht das Ergebnis. Fallback: (1.0, 1.0) mit Warnung.
    """
    if base_name in spacing_cache:
        return spacing_cache[base_name]

    candidates = [
        os.path.join(nii_root, f"{base_name}.nii.gz"),
        os.path.join(nii_root, f"{base_name}.nii"),
    ]
    for p in candidates:
        if os.path.exists(p):
            try:
                nii = nib.load(p)
                zooms = nii.header.get_zooms()
                # NIfTI: (dx, dy, dz, ...) — wir brauchen (dy, dx) für 2D-EDT
                # Viele Pipelines legen (x,y,...) an; unsere Hausdorff-Funktion erwartet (dy, dx):
                if len(zooms) >= 2:
                    dx, dy = float(zooms[0]), float(zooms[1])
                    spacing = (dy, dx)
                    spacing_cache[base_name] = spacing
                    return spacing
            except Exception as e:
                logging.warning(f"Kann NIfTI laden, aber Header nicht lesbar für {base_name}: {e}")

    logging.warning(f"Kein NIfTI für {base_name} gefunden → spacing=(1.0, 1.0) als Fallback.")
    spacing_cache[base_name] = (1.0, 1.0)
    return (1.0, 1.0)

# ---------------- Hilfsfunktionen ----------------
def _check_binary_2d(a: np.ndarray) -> np.ndarray:
    if a.ndim != 2:
        raise ValueError("Erwarte 2D-Maske (ein Slice).")
    return (a > 0).astype(np.uint8)

def _surface_2d(mask: np.ndarray) -> np.ndarray:
    if mask.sum() == 0:
        return mask.astype(bool)
    eroded = ndi.binary_erosion(mask, iterations=1, border_value=0)
    surf = mask.astype(bool) & (~eroded)
    return surf

def _surface_distances_2d(A: np.ndarray, B: np.ndarray, spacing=(1.0, 1.0)) -> np.ndarray:
    if B.sum() == 0:
        d = np.full(A.shape, np.inf, dtype=float)
    else:
        d = ndi.distance_transform_edt(~B.astype(bool), sampling=spacing)
    A_surf = _surface_2d(A)
    return d[A_surf]

def hausdorff_2d(mask1: np.ndarray, mask2: np.ndarray, spacing=(1.0, 1.0), percentile: float | None = None) -> float:
    a = _check_binary_2d(mask1)
    b = _check_binary_2d(mask2)

    if a.sum() == 0 and b.sum() == 0:
        return 0.0
    if a.sum() == 0 or b.sum() == 0:
        return float("inf")

    d_ab = _surface_distances_2d(a, b, spacing)
    d_ba = _surface_distances_2d(b, a, spacing)
    all_d = np.concatenate([d_ab, d_ba])

    if all_d.size == 0:
        return 0.0

    return float(np.max(all_d) if percentile is None else np.percentile(all_d, percentile))

# ---------------- Einzeldatei-Verarbeitung ----------------
def process_single_file_hd(mask_filename: str):
    """
    Erwartet Masken wie: <basename>_slice_{N}_mask.png
    Sucht dazu:          <basename>.nii.gz_slice_{N-1}_segmentation.png
    (lass das so — dein Schema funktioniert bereits)
    """
    base_name = mask_filename.split("_slice_")[0]  # z.B. "spleen_63"
    slice_number = mask_filename.split("_slice_")[-1].split("_")[0]
    slice_number_converted = int(slice_number) - 1
    segmentation_filename = f"{base_name}.nii.gz_slice_{slice_number_converted}_segmentation.png"

    mask_png_path = os.path.join(mask_png_folder, mask_filename)
    segmentation_path = os.path.join(segmentation_results_folder, segmentation_filename)

    if not os.path.exists(segmentation_path):
        logging.warning(f"Segmentationsdatei für {mask_filename} nicht gefunden!")
        return None

    try:
        # 1) Spacing aus NIfTI holen (pro Volume)
        spacing = _get_spacing_from_nifti(base_name)  # (dy, dx) in mm

        # 2) Masken laden
        mask_png = cv2.imread(mask_png_path, cv2.IMREAD_GRAYSCALE)
        segmentation = cv2.imread(segmentation_path, cv2.IMREAD_GRAYSCALE)

        if mask_png is None or segmentation is None:
            logging.error(f"Fehler beim Laden: {mask_filename}")
            return None

        # (Optional) Größenabgleich — wenn deine Pipeline garantiert gleiche Shapes liefert, kann dieser Block weg
        if mask_png.shape != segmentation.shape:
            logging.warning(f"Resize {base_name} slice {slice_number}: {segmentation.shape} -> {mask_png.shape}")
            segmentation = cv2.resize(segmentation, (mask_png.shape[1], mask_png.shape[0]), interpolation=cv2.INTER_NEAREST)

        mask_bin = (mask_png > 0).astype(np.uint8)
        seg_bin  = (segmentation > 0).astype(np.uint8)

        # 3) HD / HD95 mit KORREKTEM spacing
        hd   = hausdorff_2d(mask_bin, seg_bin, spacing=spacing, percentile=None)
        hd95 = hausdorff_2d(mask_bin, seg_bin, spacing=spacing, percentile=95)

        logging.info(f"{mask_filename}: HD = {hd:.3f} mm | HD95 = {hd95:.3f} mm (spacing={spacing})")
        return mask_filename, hd, hd95

    except Exception as e:
        logging.error(f"Fehler beim Verarbeiten von {mask_filename}: {e}")
        return None

# ---------------- Parallelisieren & Sammeln ----------------
results = []
with ThreadPoolExecutor() as executor:
    futures = [
        executor.submit(process_single_file_hd, fn)
        for fn in os.listdir(mask_png_folder)
        if fn.endswith(".png")
    ]
    results = [f.result() for f in futures if f.result() is not None]

# ---------------- Speichern & Visualisieren ----------------
if results:
    csv_path = "MedSAM_Spleen_hausdorff_results.csv"
    with open(csv_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Maskenname", "Hausdorff_mm", "HD95_mm"])
        writer.writerows(results)
    logging.info(f"CSV gespeichert: {csv_path}")

    hd_vals   = [r[1] for r in results if np.isfinite(r[1])]
    hd95_vals = [r[2] for r in results if np.isfinite(r[2])]

    avg_hd = np.mean(hd_vals) if hd_vals else None
    avg_hd95 = np.mean(hd95_vals) if hd95_vals else None

    if hd_vals:
        plt.figure(figsize=(8, 6))
        plt.hist(hd_vals, bins=20, color='blue', alpha=0.7, edgecolor='black')
        plt.title('Distribution of Hausdorff Distance (mm)')
        plt.xlabel('HD (mm)'); plt.ylabel('Frequency')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        if avg_hd is not None:
            plt.axvline(avg_hd, color='red', linestyle='dashed', linewidth=1.5, label=f'Avg HD: {avg_hd:.3f} mm')
            plt.legend()
        plot_path_hd = os.path.join("data", "Spleen", "hausdorff_histogram_MedSAM_Spleen.png")
        plt.savefig(plot_path_hd, dpi=150, bbox_inches='tight'); plt.show()
        logging.info(f"HD-Histogramm gespeichert: {plot_path_hd}")

    if hd95_vals:
        plt.figure(figsize=(8, 6))
        plt.hist(hd95_vals, bins=20, color='green', alpha=0.7, edgecolor='black')
        plt.title('Distribution of 95th Percentile Hausdorff Distance (HD95, mm)')
        plt.xlabel('HD95 (mm)'); plt.ylabel('Frequency')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        if avg_hd95 is not None:
            plt.axvline(avg_hd95, color='red', linestyle='dashed', linewidth=1.5, label=f'Avg HD95: {avg_hd95:.3f} mm')
            plt.legend()
        plot_path_hd95 = os.path.join("data", "Spleen", "hausdorff95_histogram_MedSAM_Spleen.png")
        plt.savefig(plot_path_hd95, dpi=150, bbox_inches='tight'); plt.show()
        logging.info(f"HD95-Histogramm gespeichert: {plot_path_hd95}")
else:
    logging.info("Keine HD/HD95-Werte berechnet!")

# %%
import os
import numpy as np
import cv2
import logging
import csv
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor

# ---------------- Logging ----------------
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# ---------------- Pfade ----------------
mask_png_folder = os.path.join("data", "Spleen", "output_masks_updated")
segmentation_results_folder = os.path.join("data", "Spleen", "segmentation_results")

# ---------------- IoU ----------------
def iou_2d(mask1: np.ndarray, mask2: np.ndarray) -> float:
    """
    Intersection over Union für 2D-Binärmasken.
    IoU = |A ∩ B| / |A ∪ B|
    Sonderfall: beide leer -> IoU = 1.0
    """
    a = (mask1 > 0).astype(np.uint8)
    b = (mask2 > 0).astype(np.uint8)
    inter = np.logical_and(a, b).sum()
    union = np.logical_or(a, b).sum()
    if union == 0:
        return 1.0
    return inter / union

# ---------------- Einzeldatei-Verarbeitung ----------------
def process_single_file_iou(mask_filename: str):
    """
    Erwartet Masken wie: <basename>_slice_{N}_mask.png
    Sucht dazu:          <basename>.nii.gz_slice_{N-1}_segmentation.png
    (gleiches Schema wie in deinem HD-Code)
    """
    base_name = mask_filename.split("_slice_")[0]
    slice_number = mask_filename.split("_slice_")[-1].split("_")[0]
    slice_number_converted = int(slice_number) - 1
    segmentation_filename = f"{base_name}.nii.gz_slice_{slice_number_converted}_segmentation.png"

    mask_png_path = os.path.join(mask_png_folder, mask_filename)
    segmentation_path = os.path.join(segmentation_results_folder, segmentation_filename)

    if not os.path.exists(segmentation_path):
        logging.warning(f"Segmentationsdatei für {mask_filename} nicht gefunden!")
        return None

    try:
        # Masken laden (grau) und binär machen
        mask_png = cv2.imread(mask_png_path, cv2.IMREAD_GRAYSCALE)
        segmentation = cv2.imread(segmentation_path, cv2.IMREAD_GRAYSCALE)

        if mask_png is None or segmentation is None:
            logging.error(f"Fehler beim Laden: {mask_filename}")
            return None

        # Falls Formen abweichen, Segmentation auf Maske bringen (Nearest)
        if mask_png.shape != segmentation.shape:
            logging.warning(f"Resize {base_name} slice {slice_number}: {segmentation.shape} -> {mask_png.shape}")
            segmentation = cv2.resize(segmentation, (mask_png.shape[1], mask_png.shape[0]), interpolation=cv2.INTER_NEAREST)

        mask_bin = (mask_png > 0).astype(np.uint8)
        seg_bin  = (segmentation > 0).astype(np.uint8)

        # IoU berechnen
        iou_val = iou_2d(mask_bin, seg_bin)
        logging.info(f"{mask_filename}: IoU = {iou_val:.4f}")
        return mask_filename, iou_val

    except Exception as e:
        logging.error(f"Fehler beim Verarbeiten von {mask_filename}: {e}")
        return None

# ---------------- Parallelisieren & Sammeln ----------------
iou_results = []
with ThreadPoolExecutor() as executor:
    futures = [
        executor.submit(process_single_file_iou, fn)
        for fn in os.listdir(mask_png_folder)
        if fn.endswith(".png")
    ]
    iou_results = [f.result() for f in futures if f.result() is not None]

# ---------------- Speichern & Visualisieren ----------------
if iou_results:
    # CSV speichern
    csv_path = "MedSAM_Spleen_iou_results.csv"
    with open(csv_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Maskenname", "IoU"])
        writer.writerows(iou_results)
    logging.info(f"CSV gespeichert: {csv_path}")

    # Histogramm
    iou_vals = [r[1] for r in iou_results]
    avg_iou = float(np.mean(iou_vals)) if iou_vals else None

    plt.figure(figsize=(8, 6))
    plt.hist(iou_vals, bins=20, color='blue', alpha=0.7, edgecolor='black')
    plt.title('Distribution of Intersection over Union (IoU)')
    plt.xlabel('IoU')
    plt.ylabel('Frequency')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    if avg_iou is not None:
        plt.axvline(avg_iou, color='red', linestyle='dashed', linewidth=1.5, label=f'Avg IoU: {avg_iou:.4f}')
        plt.legend()

    plot_path = os.path.join("data", "Spleen", "iou_histogram_MedSAM_Spleen.png")
    plt.savefig(plot_path, dpi=150, bbox_inches='tight')
    plt.show()
    logging.info(f"IoU-Histogramm gespeichert: {plot_path}")
else:
    logging.info("Keine IoU-Werte berechnet!")

# %%
import os
import numpy as np
import cv2
import logging
import csv
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
from scipy import ndimage as ndi
import nibabel as nib

# ---------------- Logging ----------------
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# ---------------- Pfade ----------------
mask_png_folder = os.path.join("data", "Spleen", "output_masks_updated")
segmentation_results_folder = os.path.join("data", "Spleen", "segmentation_results")
nii_root = os.path.join("data", "Spleen", "output_images")  # <— hier liegen deine .nii.gz

# ---------------- Parameter ----------------
tolerance_mm = 1.0  # Surface-Dice Toleranz in Millimetern (z.B. 1.0 oder 2.0)

# ---------------- NIfTI Spacing Cache ----------------
spacing_cache = {}  # base_name -> (dy, dx)

def get_spacing_dy_dx(base_name: str):
    """Hole (dy, dx) in mm aus <nii_root>/<base_name>.nii(.gz); fallback (1,1) mit Warnung."""
    if base_name in spacing_cache:
        return spacing_cache[base_name]
    for ext in (".nii.gz", ".nii"):
        p = os.path.join(nii_root, base_name + ext)
        if os.path.exists(p):
            nii = nib.load(p)
            zooms = nii.header.get_zooms()
            # NIfTI: (dx, dy, dz, ...) → wir brauchen (dy, dx) für EDT
            dx, dy = float(zooms[0]), float(zooms[1])
            spacing_cache[base_name] = (dy, dx)
            return spacing_cache[base_name]
    logging.warning(f"Kein NIfTI für {base_name} gefunden – spacing=(1.0, 1.0) als Fallback.")
    spacing_cache[base_name] = (1.0, 1.0)
    return spacing_cache[base_name]

# ---------------- Surface-Dice Hilfsfunktionen ----------------
def _bin2d(a):
    if a.ndim != 2:
        raise ValueError("Erwarte 2D-Maske.")
    return (a > 0).astype(np.uint8)

def _surface(mask):
    # Randpixel: Maske & ~Erosion
    if mask.sum() == 0:
        return mask.astype(bool)
    eroded = ndi.binary_erosion(mask, iterations=1, border_value=0)
    return mask.astype(bool) & (~eroded)

def surface_dice_2d(pred, gt, spacing, tol_mm: float):
    """
    Surface Dice in [0,1]: Anteil der Oberflächenpunkte beider Masken,
    deren Abstand zur jeweils anderen Oberfläche <= tol_mm ist.
    """
    p = _bin2d(pred); g = _bin2d(gt)
    ps = _surface(p); gs = _surface(g)

    # Sonderfälle
    if p.sum() == 0 and g.sum() == 0:
        return 1.0
    if ps.sum() == 0 and gs.sum() == 0:
        return 1.0
    if ps.sum() == 0 or gs.sum() == 0:
        return 0.0

    # Distanzkarten (in mm dank spacing)
    d_to_g = ndi.distance_transform_edt(~g.astype(bool), sampling=spacing)
    d_to_p = ndi.distance_transform_edt(~p.astype(bool), sampling=spacing)

    p_ok = (d_to_g[ps] <= tol_mm).sum()
    g_ok = (d_to_p[gs] <= tol_mm).sum()
    return (p_ok + g_ok) / (ps.sum() + gs.sum())

# ---------------- Einzeldatei-Verarbeitung ----------------
def process_single_file_surfacedice(mask_filename: str):
    """
    Erwartet Masken:    <base>_slice_{N}_mask.png
    Sucht Segmentierung: <base>.nii.gz_slice_{N-1}_segmentation.png  (dein bestehendes Schema)
    """
    base_name = mask_filename.split("_slice_")[0]              # z.B. spleen_63
    slice_number = mask_filename.split("_slice_")[-1].split("_")[0]
    slice_number_converted = int(slice_number) - 1
    segmentation_filename = f"{base_name}.nii.gz_slice_{slice_number_converted}_segmentation.png"

    mask_path = os.path.join(mask_png_folder, mask_filename)
    seg_path  = os.path.join(segmentation_results_folder, segmentation_filename)

    if not os.path.exists(seg_path):
        logging.warning(f"Segmentationsdatei für {mask_filename} nicht gefunden!")
        return None

    # Spacing (dy, dx) holen
    spacing = get_spacing_dy_dx(base_name)

    # Bilder laden
    mask_png = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    seg_png  = cv2.imread(seg_path, cv2.IMREAD_GRAYSCALE)
    if mask_png is None or seg_png is None:
        logging.error(f"Fehler beim Laden: {mask_filename}")
        return None

    # Shapes angleichen (falls nötig)
    if mask_png.shape != seg_png.shape:
        logging.warning(f"Resize {base_name} slice {slice_number}: {seg_png.shape} -> {mask_png.shape}")
        seg_png = cv2.resize(seg_png, (mask_png.shape[1], mask_png.shape[0]), interpolation=cv2.INTER_NEAREST)

    # Binär
    m = (mask_png > 0).astype(np.uint8)
    s = (seg_png  > 0).astype(np.uint8)

    sd = surface_dice_2d(s, m, spacing=spacing, tol_mm=tolerance_mm)
    logging.info(f"{mask_filename}: Surface Dice ({tolerance_mm} mm) = {sd:.4f} (spacing={spacing})")
    return mask_filename, float(sd)

# ---------------- Parallelisieren & Sammeln ----------------
sd_results = []
with ThreadPoolExecutor() as executor:
    futures = [
        executor.submit(process_single_file_surfacedice, fn)
        for fn in os.listdir(mask_png_folder)
        if fn.endswith(".png")
    ]
    sd_results = [f.result() for f in futures if f.result() is not None]

# ---------------- Speichern & Visualisieren ----------------
if sd_results:
    csv_name = f"MedSAM_Spleen_surface_dice_{str(tolerance_mm).replace('.','_')}mm_results.csv"
    with open(csv_name, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Maskenname", f"SurfaceDice_{tolerance_mm}mm"])
        writer.writerows(sd_results)
    logging.info(f"CSV gespeichert: {csv_name}")

    sd_vals = [r[1] for r in sd_results]
    avg_sd = float(np.mean(sd_vals)) if sd_vals else None

    plt.figure(figsize=(8, 6))
    plt.hist(sd_vals, bins=20, color='blue', alpha=0.7, edgecolor='black')
    plt.title(f'Distribution of Surface Dice ({tolerance_mm} mm)')
    plt.xlabel('Surface Dice')
    plt.ylabel('Frequency')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    if avg_sd is not None:
        plt.axvline(avg_sd, color='red', linestyle='dashed', linewidth=1.5,
                    label=f'Avg SD ({tolerance_mm} mm): {avg_sd:.4f}')
        plt.legend()

    plot_path = os.path.join("data", "Spleen", f"surface_dice_histogram_{str(tolerance_mm).replace('.','_')}mm_MedSAM_Spleen.png")
    plt.savefig(plot_path, dpi=150, bbox_inches='tight')
    plt.show()
    logging.info(f"Surface-Dice-Histogramm gespeichert: {plot_path}")
else:
    logging.info("Keine Surface-Dice-Werte berechnet!")

# %%
# --- Save results (CSV) & standardized histogram (Spleen – MedSAM) ---
import os, csv, numpy as np
import matplotlib.pyplot as plt

if dice_scores:
    # CSV (konsistent benannt)
    out_csv = r"results\Spleen\dice_MedSAM_Spleen.csv"
    os.makedirs(os.path.dirname(out_csv), exist_ok=True)
    with open(out_csv, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["Filename", "Dice"])
        writer.writerows(dice_scores)

    # Werte + Mittelwert
    dice_values = np.array([score for _, score in dice_scores], dtype=float)
    mean_val = float(np.mean(dice_values))
    print(f"Mean Dice (Spleen, MedSAM): {mean_val:.4f}")

    # Einheitliches Histogramm
    bins = np.linspace(0, 1, 21)
    plt.figure(figsize=(8, 6))
    plt.hist(dice_values, bins=bins, edgecolor="black")
    plt.xlim(0, 1); plt.ylim(bottom=0)
    plt.xlabel("Dice Score"); plt.ylabel("Frequency")
    plt.axvline(mean_val, ls="--", lw=1.5, color="red", label=f"Mean: {mean_val:.4f}")
    plt.legend(loc="upper left", framealpha=0.9)
    plt.title("Distribution of Dice Scores (Spleen, MedSAM)")
    plt.tight_layout()

    # Einheitlicher Speicherort/Name für LaTeX
    out_png = r"PICs\dice_score_histogram_MedSAM_Spleen.png"
    os.makedirs(os.path.dirname(out_png), exist_ok=True)
    plt.savefig(out_png, dpi=200, bbox_inches="tight")
    plt.close()
else:
    logging.info("Keine Dice Scores berechnet!")

# %%
'''
import os
import cv2
import matplotlib.pyplot as plt

# Verzeichnisse
mask_png_folder = os.path.join("data", "Lung Tumors", "output_2_masks_updated")
segmentation_results_folder = os.path.join("data", "Lung Tumors", "segmentation_2_results")

# Funktion zur Anzeige von drei Bildern
def show_three_images(mask_filename, slice_number):
    """
    Zeigt die Originalmaske, die erstellte Maske und die Segmentierungsvisualisierung.
    :param mask_filename: Name der Originalmaske im Ordner `output_2_masks_updated`.
    :param slice_number: Nummer des Slices für die Zuordnung von Segmentierung und Visualisierung.
    """
    # Anpassung des Dateinamens
    base_name = mask_filename.split("_slice_")[0]
    segmentation_mask_filename = f"{base_name}.nii.gz_slice_{slice_number}_segmentation.png"
    segmentation_visual_filename = f"{base_name}.nii.gz_slice_{slice_number}_visualization.png"

    # Pfade zu den Dateien
    mask_png_path = os.path.join(mask_png_folder, mask_filename)
    segmentation_mask_path = os.path.join(segmentation_results_folder, segmentation_mask_filename)
    segmentation_visual_path = os.path.join(segmentation_results_folder, segmentation_visual_filename)

    # Prüfen, ob die Dateien existieren
    if not os.path.exists(mask_png_path):
        print(f"Die Originalmaske {mask_filename} wurde nicht gefunden!")
        return
    if not os.path.exists(segmentation_mask_path):
        print(f"Die erstellte Maske {segmentation_mask_filename} wurde nicht gefunden!")
        return
    if not os.path.exists(segmentation_visual_path):
        print(f"Die Segmentierungsvisualisierung {segmentation_visual_filename} wurde nicht gefunden!")
        return

    # Dateien laden
    original_mask = cv2.imread(mask_png_path, cv2.IMREAD_GRAYSCALE)
    segmentation_mask = cv2.imread(segmentation_mask_path, cv2.IMREAD_GRAYSCALE)
    segmentation_visual = cv2.imread(segmentation_visual_path)

    # Darstellung
    plt.figure(figsize=(18, 6))

    # Originalmaske
    plt.subplot(1, 3, 1)
    plt.imshow(original_mask, cmap="gray")
    plt.title("Originalmaske")
    plt.axis("off")

    # Generierte Maske
    plt.subplot(1, 3, 2)
    plt.imshow(segmentation_mask, cmap="gray")
    plt.title("Erstellte Maske")
    plt.axis("off")

    # Segmentierungsvisualisierung
    plt.subplot(1, 3, 3)
    plt.imshow(segmentation_visual)
    plt.title("Segmentierungsvisualisierung")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# Beispielaufruf
# Geben Sie die Originalmaske und die gewünschte Slice-Nummer ein
mask_filename = "lung_001_slice_01_segmentation.png"  # Beispiel
slice_number = 0  # Beispiel-Slice-Nummer (0-basiert)
show_three_images(mask_filename, slice_number)
'''
